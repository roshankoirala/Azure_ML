# %%
from azureml.core import Workspace, Environment, ScriptRunConfig, Experiment
from azureml.core.conda_dependencies import CondaDependencies

# %% [markdown]
# # Model from registered data
#
# In this notebook we retrive a registered data in a python script. We provide name of the dataset as an argument of the `ScriptRunConfig` object. The script parse the dataset name. In this way we don't have to modify the script if we change the dataset in the model.
#
# Once we retrive the data we can do all the works based on it. In the script we are minimalistic with the data preprocessing and calculate the length of the data.

# %%
ws = Workspace.from_config()

# %%
env = Environment('myenv')
packages = CondaDependencies.create(conda_packages=['pip'], 
                                   pip_packages=['azureml-defaults', 
                                                 'azureml-dataprep[pandas]'])
env.python.conda_dependencies = packages 

script_config = ScriptRunConfig(source_directory='.', 
                               script='script_5.py', 
                               arguments=['--ds', 'Iris Data'], 
                               environment=env)

# %%
experiment = Experiment(workspace=ws, name='azureml-demo-exp')
run = experiment.submit(config=script_config)
run.wait_for_completion(show_output=True)
# Out:
# RunId: azureml-demo-exp_1633634199_0a1f5ab2
# Web View: https://ml.azure.com/runs/azureml-demo-exp_1633634199_0a1f5ab2?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
#
# Streaming azureml-logs/60_control_log.txt
# ...
#
# [2021-10-07T19:16:41.272249] Using urllib.request Python 3.0 or later
# Streaming log file azureml-logs/60_control_log.txt
# Running: ['cmd.exe', '/c', 'C:\\Users\\rkoirala\\AppData\\Local\\Temp\\azureml_runs\\azureml-demo-exp_1633634199_0a1f5ab2\\azureml-environment-setup/conda_env_checker.bat']
# Starting the daemon thread to refresh tokens in background for process with pid = 3412
# Materialized conda environment not found on target: C:\Users\rkoirala/.azureml/envs/azureml_a6ffb6e5046b9ac0627443e851ebf8e2
#
#
# [2021-10-07T19:16:41.519889] Logging experiment preparation status in history service.
# ...
