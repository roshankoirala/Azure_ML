# %% [markdown]
# # Introduction
#
# In this notebook we investigate `Pipeline` object of `azureml-sdk`. One of the great thing about pipeline is that we can use it to scheule periodic run of the model for the batch inference.

# %%
from azureml.core import Workspace, Environment, Experiment
from azureml.core.environment import CondaDependencies
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.core.runconfig import RunConfiguration
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineData, Pipeline
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (numpy 1.20.2 (c:\users\rkoirala\anaconda3\lib\site-packages), Requirement.parse('numpy<=1.19.3; sys_platform == "win32"'), {'azureml-dataset-runtime'}).

# %%
ws = Workspace.from_config()

# %% [markdown]
# # Create an Environment

# %%
myenv = Environment(name='env_azure_pipeline')
myenv_dep = CondaDependencies.create(conda_packages=['pandas', 'scikit-learn', 'pip'], 
                                    pip_packages=['azureml-defaults'])
myenv.python.conda_dependencies = myenv_dep
myenv.register(ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "env_azure_pipeline",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-defaults~=1.30.0"
#                     ]
#                 },
#                 "pandas",
#                 "scikit-learn",
#                 "pip"
#             ],
#             "name": "azureml_787a1ecd36f533049488c5a225359bf2"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "7"
# }

# %% [markdown]
# # Compute target in the cloud

# %%
compute_name = 'rk-test-compute'

compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', 
                                                       max_nodes=2)

rk_cluster = ComputeTarget.create(ws, compute_name, compute_config)
rk_cluster.wait_for_completion(show_output=True)
# Out:
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
run_config = RunConfiguration()
run_config.target = rk_cluster
run_config.environment = myenv

# %% [markdown]
# # Pipeline and steps
#
# This is the new step here. This step is similar to the previous notebook where we create `Experiment` object and submit the model via python script. But only this time we submit the pipeline object which may consists of one or more than one steps.
#
# ##### Check for `OutputFileDatasetConfig` option!

# %%
input_ds = ws.datasets.get('Iris Data')
datafolder = PipelineData('datafolder', datastore=ws.get_default_datastore())

# Step 01 - Data Preprocessing 
preprocess_step = PythonScriptStep(name='01 data_preprocessing', 
                                   source_directory='.', 
                                   script_name='pipeline_data_prepare.py', 
                                   arguments=['--datafolder', datafolder],
                                   inputs=[input_ds.as_named_input('raw_data')], 
                                   outputs=[datafolder],
                                   runconfig=run_config)

# Step 02 - Train Model 
model_train_step = PythonScriptStep(name='02 model_training', 
                                   source_directory='.', 
                                   script_name='pipeline_model_training.py', 
                                   arguments=['--datafolder', datafolder],
                                   inputs=[datafolder],
                                   runconfig=run_config)

# %%
# Construct the pipeline 
train_pipeline = Pipeline(workspace=ws,
                          steps=[preprocess_step, model_train_step])

# Create the experiment 
experiment = Experiment(workspace=ws, name='azureml-demo-exp')

# Run the experiment with pipeline
pipeline_run = experiment.submit(train_pipeline, 
                                 regenerate_outputs=True)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step 01 data_preprocessing [94bae01d][27e76576-5f33-4ddd-921a-c2dd1006dcd2], (This step will run and generate new outputs)
# Created step 02 model_training [4e408fd0][a3b02f09-94e5-499b-8285-41268f060607], (This step will run and generate new outputs)
# Submitted PipelineRun a561e068-8103-4117-9de9-b446ed437b19
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a561e068-8103-4117-9de9-b446ed437b19?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# PipelineRunId: a561e068-8103-4117-9de9-b446ed437b19
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a561e068-8103-4117-9de9-b446ed437b19?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# PipelineRun Status: Running
#
#
# StepRunId: 9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/9ce9ea22-e38e-4f97-a0b6-f13db77644bb?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# StepRun( 01 data_preprocessing ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# ========================================================================================================================
# 2021-10-14T18:47:20Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24565 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-14T18:47:21Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore
# 2021-10-14T18:47:21Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:47:21Z Starting output-watcher...
# 2021-10-14T18:47:21Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-10-14T18:47:21Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-10-14T18:47:21Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8
# 01bf7da0a88c: Pulling fs layer
# f3b4a5f15c7a: Pulling fs layer
# 57ffbe87baa1: Pulling fs layer
# 86120caa19f5: Pulling fs layer
# c0f2d44469de: Pulling fs layer
# 638bc09d59ce: Pulling fs layer
# cec7eddb8044: Pulling fs layer
# 31cda9815495: Pulling fs layer
# a1b48f84f0d1: Pulling fs layer
# 484f821166bc: Pulling fs layer
# 6d70e314b196: Pulling fs layer
# 24af3ff900e4: Pulling fs layer
# 6ae63873e2d8: Pulling fs layer
# 5381d6eb3fc7: Pulling fs layer
# 12fd024c3d8d: Pulling fs layer
# b2d41f2093cf: Pulling fs layer
# 556fcbae229e: Pulling fs layer
# 17df31e62267: Pulling fs layer
# d3bbcc54e130: Pulling fs layer
# 2fd9415cdeeb: Pulling fs layer
# c0f2d44469de: Waiting
# 638bc09d59ce: Waiting
# cec7eddb8044: Waiting
# 31cda9815495: Waiting
# a1b48f84f0d1: Waiting
# 484f821166bc: Waiting
# 6d70e314b196: Waiting
# 24af3ff900e4: Waiting
# 6ae63873e2d8: Waiting
# 5381d6eb3fc7: Waiting
# 12fd024c3d8d: Waiting
# b2d41f2093cf: Waiting
# 86120caa19f5: Waiting
# 556fcbae229e: Waiting
# 17df31e62267: Waiting
# d3bbcc54e130: Waiting
# 2fd9415cdeeb: Waiting
# 57ffbe87baa1: Verifying Checksum
# 57ffbe87baa1: Download complete
# f3b4a5f15c7a: Verifying Checksum
# f3b4a5f15c7a: Download complete
# c0f2d44469de: Verifying Checksum
# c0f2d44469de: Download complete
# 638bc09d59ce: Verifying Checksum
# 638bc09d59ce: Download complete
# 01bf7da0a88c: Verifying Checksum
# 01bf7da0a88c: Download complete
# 31cda9815495: Verifying Checksum
# 31cda9815495: Download complete
# a1b48f84f0d1: Verifying Checksum
# a1b48f84f0d1: Download complete
# cec7eddb8044: Verifying Checksum
# cec7eddb8044: Download complete
# 86120caa19f5: Download complete
# 6d70e314b196: Verifying Checksum
# 6d70e314b196: Download complete
# 6ae63873e2d8: Verifying Checksum
# 6ae63873e2d8: Download complete
# 24af3ff900e4: Verifying Checksum
# 24af3ff900e4: Download complete
# 484f821166bc: Verifying Checksum
# 484f821166bc: Download complete
# 12fd024c3d8d: Verifying Checksum
# 12fd024c3d8d: Download complete
# 556fcbae229e: Verifying Checksum
# 556fcbae229e: Download complete
# 5381d6eb3fc7: Verifying Checksum
# 5381d6eb3fc7: Download complete
# 01bf7da0a88c: Pull complete
# f3b4a5f15c7a: Pull complete
# 17df31e62267: Verifying Checksum
# 17df31e62267: Download complete
# 57ffbe87baa1: Pull complete
# 2fd9415cdeeb: Verifying Checksum
# 2fd9415cdeeb: Download complete
# d3bbcc54e130: Verifying Checksum
# d3bbcc54e130: Download complete
# 86120caa19f5: Pull complete
# c0f2d44469de: Pull complete
# 638bc09d59ce: Pull complete
# b2d41f2093cf: Verifying Checksum
# b2d41f2093cf: Download complete
# cec7eddb8044: Pull complete
# 31cda9815495: Pull complete
# a1b48f84f0d1: Pull complete
# 484f821166bc: Pull complete
# 6d70e314b196: Pull complete
# 24af3ff900e4: Pull complete
# 6ae63873e2d8: Pull complete
# 5381d6eb3fc7: Pull complete
# 12fd024c3d8d: Pull complete
# b2d41f2093cf: Pull complete
# 556fcbae229e: Pull complete
# 17df31e62267: Pull complete
# d3bbcc54e130: Pull complete
# 2fd9415cdeeb: Pull complete
# Digest: sha256:5eb7255ec89630de6e4ff750bb1389f57f023cf47b17091595238343085ade11
# Status: Downloaded newer image for 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8:latest
# 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8:latest
# 2021-10-14T18:47:55Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:47:55Z Check if container 9ce9ea22-e38e-4f97-a0b6-f13db77644bb already exist exited with 0,
#
# 1284e49017428f938360e5efe5de7ba42f263e443933148c4b89e4f9c2ed11a9
# 2021-10-14T18:48:02Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-10-14T18:48:02Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2b62c46aae5c9d42531df78bc9e25512-c9bf5bbfc1197dc4-01 -sshRequired=false]
# 2021/10/14 18:48:02 Got JobInfoJson from env
# 2021/10/14 18:48:02 Starting App Insight Logger for task:  containerSetup
# 2021/10/14 18:48:02 Version: 3.0.01744.0001 Branch: .SourceBranch Commit: f3a69a2
# 2021/10/14 18:48:02 Entered ContainerSetupTask - Preparing infiniband
# 2021/10/14 18:48:02 Starting infiniband setup
# 2021/10/14 18:48:02 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/10/14 18:48:02 Returning Python Version as 3.6
# 2021/10/14 18:48:02 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/10/14 18:48:02 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021-10-14T18:48:02Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/10/14 18:48:02 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021-10-14T18:48:02Z Not setting up Infiniband in Container
# 2021/10/14 18:48:02 Not setting up Infiniband in Container
# 2021/10/14 18:48:02 Not setting up Infiniband in Container
# 2021/10/14 18:48:02 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/10/14 18:48:02 Returning Python Version as 3.6
# 2021/10/14 18:48:02 sshd inside container not required for job, skipping setup.
# 2021/10/14 18:48:02 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/10/14 18:48:02 App Insight Client has already been closed
# 2021/10/14 18:48:02 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-10-14T18:48:02Z Starting docker container succeeded.
# 2021-10-14T18:48:07Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:48:07Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:48:07Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2021/10/14 18:47:20 Got JobInfoJson from env
# >>>   2021/10/14 18:47:20 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/10/14 18:47:20 Version: 3.0.01744.0001 Branch: .SourceBranch Commit: f3a69a2
# >>>   2021/10/14 18:47:20 Got JobInfoJson from env
# >>>   2021/10/14 18:47:20 runtime.GOOS linux
# >>>   2021/10/14 18:47:20 Checking if '/tmp' exists
# >>>   2021/10/14 18:47:20 Reading dyanamic configs
# >>>   2021/10/14 18:47:20 Container sas url: https://baiscriptseastus2prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=0zSJlZiBvTfbGrZHmFBZqzDes0PMmYkeROmANx9hhuo%3D
# >>>   2021/10/14 18:47:20 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/azsecpack.variables: no such file or directory
# >>>   2021/10/14 18:47:20 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installer on host: true. Is Azsecpack installation enabled: false,
# >>>   2021/10/14 18:47:20 Starting Azsecpack installation on machine: 360a4a8ddc0c41b4a9ae341f21cb810e000001#4ef6e02a-f252-4618-a1dc-03bd2f93157d#54245888-2ffe-41fa-b080-67a29997b41c#rg-dataservices-sandbox-01#ds_dev_01#rk-test-compute#tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d
# >>>   2021/10/14 18:47:20 Is Azsecpack enabled: false, GetDisableVsatlsscan: true
# >>>   2021/10/14 18:47:20 Turning off azsecpack, if it is already running
# >>>   2021/10/14 18:47:20 Start deleting Azsecpack installation cronjob...
# >>>   2021/10/14 18:47:20 Start checking if Azsecpack is running...
# >>>   2021/10/14 18:47:20 Azsecpack is not running. No need to stop Azsecpack processes.
# >>>   2021/10/14 18:47:20 bypass systemd resolved
# >>>   2021/10/14 18:47:20 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/10/14 18:47:20 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:47:20 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:47:20 Get GPU count failed with err: The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.,
# >>>   2021/10/14 18:47:20 AMLComputeXDSEndpoint:  https://eastus2.cert.api.azureml.ms/xdsbatchai
# >>>   2021/10/14 18:47:20 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/10/14 18:47:20 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/config
# >>>   2021/10/14 18:47:20 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/10/14 18:47:20 Starting identity responder.
# >>>   2021/10/14 18:47:20 Starting identity responder.
# >>>   2021/10/14 18:47:20 Logfile used for identity responder: /mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/IdentityResponderLog-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:47:20 Logfile used for identity responder: /mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/IdentityResponderLog-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:47:20 Started Identity Responder for job.
# >>>   2021/10/14 18:47:20 Started Identity Responder for job.
# >>>   2021/10/14 18:47:20 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd
# >>>   2021/10/14 18:47:20 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/shared
# >>>   2021/10/14 18:47:20 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:20 From the policy service, the filtering patterns is: , data store is
# >>>   2021/10/14 18:47:20 Mounting job level file systems
# >>>   2021/10/14 18:47:20 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts
# >>>   2021/10/14 18:47:20 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/config/.amlcompute.datastorecredentials
# >>>   2021/10/14 18:47:20 Unmarshalling datastore credentials file...
# >>>   2021/10/14 18:47:20 Decoding map...
# >>>   2021/10/14 18:47:20 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/config/.master.runtimesastokens
# >>>   2021/10/14 18:47:20 Runtime sas tokens file not found, skipping.
# >>>   2021/10/14 18:47:20 NFS mount is not enabled
# >>>   2021/10/14 18:47:20 No Azure File Shares configured
# >>>   2021/10/14 18:47:20 Mounting blob file systems
# >>>   2021/10/14 18:47:20 Blobfuse runtime version 1.3.6
# >>>   2021/10/14 18:47:20 Mounting azureml-blobstore-03198395-8463-4a4d-8899-cb105b49c173 container from dsdev011073180542 account at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore
# >>>   2021/10/14 18:47:20 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/10/14 18:47:20 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/10/14 18:47:20 Blobfuse cache size set to 24565 MB.
# >>>   2021/10/14 18:47:20 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24565 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/10/14 18:47:21 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore
# >>>   2021/10/14 18:47:21 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore
# >>>   2021/10/14 18:47:21 Successfully mounted azureml-blobstore-03198395-8463-4a4d-8899-cb105b49c173 container from dsdev011073180542 account at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore
# >>>   2021/10/14 18:47:21 Created run_id directory: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 No unmanaged file systems configured
# >>>   2021/10/14 18:47:21 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:47:21 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:47:21 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 From the policy service, the filtering patterns is: , data store is
# >>>   2021/10/14 18:47:21 Creating working directory: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 Changing permissions for all existing files under directory: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs
# >>>   2021/10/14 18:47:21 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs/tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d
# >>>   2021/10/14 18:47:21 Change mode to 666 for file /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs/tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d/55_azureml-execution-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:47:21 Set default ACL for files under directory by running: /usr/bin/setfacl -m default:g::rwx -m default:o::rwx /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:21 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs
# >>>   2021/10/14 18:47:21 Changing permissions for all existing files under directory: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs
# >>>   2021/10/14 18:47:21 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs
# >>>   2021/10/14 18:47:21 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs/tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d
# >>>   2021/10/14 18:47:21 Change mode to 666 for file /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs/tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d/55_azureml-execution-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:47:21 Set default ACL for files under directory by running: /usr/bin/setfacl -m default:g::rwx -m default:o::rwx /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs
# >>>   2021/10/14 18:47:21 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/logs
# >>>   2021/10/14 18:47:21 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/outputs
# >>>   2021/10/14 18:47:21 Starting output-watcher...
# >>>   2021/10/14 18:47:21 Single file input dataset is enabled.
# >>>   2021/10/14 18:47:21 SidecarEnabled:: isDetonationChamber: false, useDockerContainer: true
# >>>   2021/10/14 18:47:21 SidecarEnabled:: AmlDatasetContextManagerConfig exists: false
# >>>   2021/10/14 18:47:21 SidecarEnabled:: sidecar not enabled
# >>>   2021/10/14 18:47:21 Start to pulling docker image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8
# >>>   2021/10/14 18:47:21 Start pull docker image: 0319839584634a4d8899cb105b49c173.azurecr.io
# >>>   2021/10/14 18:47:21 Getting credentials for image 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8 with url 0319839584634a4d8899cb105b49c173.azurecr.io
# >>>   2021/10/14 18:47:21 Container registry is ACR.
# >>>   2021/10/14 18:47:21 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/10/14 18:47:21 Getting ACR Credentials from EMS for environment env_azure_pipeline:7
# >>>   2021/10/14 18:47:21 Requesting XDS for registry details.
# >>>   2021/10/14 18:47:21 Attempt 1 of http call to https://eastus2.cert.api.azureml.ms/xdsbatchai/hosttoolapi/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourceGroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01/clusters/rk-test-compute/nodes/tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d?api-version=2018-02-01
# >>>   2021/10/14 18:47:21 Got container registry details from credentials service for registry address: 0319839584634a4d8899cb105b49c173.azurecr.io.
# >>>   2021/10/14 18:47:21 Writing ACR Details to file...
# >>>   2021/10/14 18:47:21 Copying ACR Details file to worker nodes...
# >>>   2021/10/14 18:47:21 Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2021/10/14 18:47:21 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/10/14 18:47:21 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/10/14 18:47:21 Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/10/14 18:47:21 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/10/14 18:47:21 EMS returned 0319839584634a4d8899cb105b49c173.azurecr.io for environment env_azure_pipeline
# >>>   2021/10/14 18:47:21 Save docker credentials for image 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8 in /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/docker_login_DFD541DA3BD49B6E
# >>>   2021/10/14 18:47:21 Start login to the docker registry
# >>>   2021/10/14 18:47:22 Successfully logged into the docker registry.
# >>>   2021/10/14 18:47:22 Start run pull docker image command
# >>>   2021/10/14 18:47:25 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 19
# >>>   FilteredData: 0.
# >>>   2021/10/14 18:47:55 Pull docker image succeeded.
# >>>   2021/10/14 18:47:55 Removed docker config dir /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/docker_login_DFD541DA3BD49B6E
# >>>   2021/10/14 18:47:55 Pull docker image time: 33.435800911s
# >>>
# >>>   2021/10/14 18:47:55 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/10/14 18:47:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:47:55 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:47:55 Setting the memory limit for docker container to be 13674 MB
# >>>   2021/10/14 18:47:55 The env variable file size is 40701 bytes
# >>>   2021/10/14 18:47:55 Creating parent cgroup '9ce9ea22-e38e-4f97-a0b6-f13db77644bb' for Containers used in Job
# >>>   2021/10/14 18:47:55 Add parent cgroup '9ce9ea22-e38e-4f97-a0b6-f13db77644bb' to container '9ce9ea22-e38e-4f97-a0b6-f13db77644bb'
# >>>   2021/10/14 18:47:55 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/10/14 18:47:55 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,9ce9ea22-e38e-4f97-a0b6-f13db77644bb,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/certs:/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,13674m,-v,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd:/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb:/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/config/.batchai.envlist,--cgroup-parent=/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/,--shm-size,2g
# >>>   2021/10/14 18:47:55 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/10/14 18:47:55 the binding /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb:/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:47:55 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,9ce9ea22-e38e-4f97-a0b6-f13db77644bb,-m,13674m,-w,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/config/.batchai.envlist,--cgroup-parent=/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/,--shm-size,2g,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb:/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb,-v,/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd:/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd,-v,/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/certs:/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/certs
# >>>   2021/10/14 18:47:55 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 9ce9ea22-e38e-4f97-a0b6-f13db77644bb -m 13674m -w /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/config/.batchai.envlist --cgroup-parent=/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/ --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb:/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb -v /mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd:/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd -v /mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/certs:/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/certs -d -it --privileged --net=host 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_28ad09a065c2eb2dfa9909287cfb26c8
# >>>   2021/10/14 18:47:55 Check if container 9ce9ea22-e38e-4f97-a0b6-f13db77644bb already exist exited with 0,
# >>>
# >>>   2021/10/14 18:47:55 Check if container 9ce9ea22-e38e-4f97-a0b6-f13db77644bb already exist exited with 0,
# >>>
# >>>   2021/10/14 18:47:55 Attempt 1 of http call to https://eastus2.api.azureml.ms/history/v1.0/private/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourceGroups/rg-dataservices-sandbox-01/providers/Microsoft.MachineLearningServices/workspaces/ds_dev_01/runs/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/spans
# >>>   2021/10/14 18:48:02 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/10/14 18:48:02 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/10/14 18:48:02 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2b62c46aae5c9d42531df78bc9e25512-c9bf5bbfc1197dc4-01 -sshRequired=false]
# >>>   2021/10/14 18:48:02 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-2b62c46aae5c9d42531df78bc9e25512-c9bf5bbfc1197dc4-01 -sshRequired=false]
# >>>   2021/10/14 18:48:02 Container ssh is not required for job type.
# >>>   2021/10/14 18:48:02 Starting docker container succeeded.
# >>>   2021/10/14 18:48:02 Starting docker container succeeded.
# >>>   2021/10/14 18:48:02 Disk space after starting docker container: 23792MB
# >>>   2021/10/14 18:48:02 SidecarEnabled:: isDetonationChamber: false, useDockerContainer: true
# >>>   2021/10/14 18:48:02 SidecarEnabled:: AmlDatasetContextManagerConfig exists: false
# >>>   2021/10/14 18:48:02 SidecarEnabled:: sidecar not enabled
# >>>   2021/10/14 18:48:02 Begin execution of runSpecialJobTask
# >>>   2021/10/14 18:48:02 Creating directory at $AZUREML_LOGDIRECTORY_PATH
# >>>   2021/10/14 18:48:02 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml-logs
# >>>   2021/10/14 18:48:02 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs
# >>>   2021/10/14 18:48:02 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_787a1ecd36f533049488c5a225359bf2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5da9547-ebe8-45fb-9402-a9076c771f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/10/14 18:48:02 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs/65_job_prep-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:48:02 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/azureml_compute_logs/65_job_prep-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:48:02 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb;/azureml-envs/azureml_787a1ecd36f533049488c5a225359bf2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5da9547-ebe8-45fb-9402-a9076c771f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/10/14 18:48:02 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/10/14 18:48:02 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-2b62c46aae5c9d42531df78bc9e25512-411b7888cacc7297-01 -t 9ce9ea22-e38e-4f97-a0b6-f13db77644bb bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/9ce9ea22-e38e-4f97-a_1417044a-18d2-4b9f-b49d-5d03972feb5f/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb;/azureml-envs/azureml_787a1ecd36f533049488c5a225359bf2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5da9547-ebe8-45fb-9402-a9076c771f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/10/14 18:48:05 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 2
# >>>   FilteredData: 0.
# >>>   2021/10/14 18:48:07 containerName:9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:48:07 sidecar containerName:9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>   2021/10/14 18:48:07 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/10/14 18:48:07 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:48:07 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:48:07 sidecar dockerLauncher:docker
# >>>   2021/10/14 18:48:07 sidecarContainerId:1284e49017428f938360e5efe5de7ba42f263e443933148c4b89e4f9c2ed11a9
# >>>   2021/10/14 18:48:07 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/10/14 18:48:07 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:48:07 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:48:07 Docker logs for 9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# >>>
# >>>   2021/10/14 18:48:07 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:02.941707] Entering job preparation.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.431561] Starting job preparation.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.431601] Extracting the control code.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.432110] Starting extract_project.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.432168] Starting to extract zip file.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.450401] Finished extracting zip file.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.454395] Using urllib.request Python 3.0 or later
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.454512] Start fetching snapshots.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.454669] Start fetching snapshot.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:04.454733] Retrieving project from snapshot: a5da9547-ebe8-45fb-9402-a9076c771f1d
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 44
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.382306] Finished fetching snapshot.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.382374] Finished fetching snapshots.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.382398] Finished extract_project.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.382512] Finished fetching and extracting the control code.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.386520] downloadDataStore - Download from datastores if requested.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.387793] Start run_history_prep.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.398230] Entering context manager injector.
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: Acquired lockfile /tmp/9ce9ea22-e38e-4f97-a0b6-f13db77644bb-datastore.lock to downloading input data references
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.875662] downloadDataStore completed
# >>>   2021/10/14 18:48:07 runSpecialJobTask: preparation: [2021-10-14T18:48:06.878804] Job preparation is complete.
# >>>   2021/10/14 18:48:07 DockerSideCarContainerLogs:
# >>>
# >>>   2021/10/14 18:48:07 DockerSideCarContainerLogs End
# >>>   2021/10/14 18:48:07 Execution of runSpecialJobTask completed
# >>>   2021/10/14 18:48:07 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/10/14 18:48:07 Process Exiting with Code:  0
# >>>   2021/10/14 18:48:07 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-10-14T18:48:07Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:48:07Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:48:07Z 127.0.0.1 slots=2 max-slots=2
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/10/14 18:48:07 Got JobInfoJson from env
# 2021/10/14 18:48:07 Starting App Insight Logger for task:  runTaskLet
# 2021/10/14 18:48:07 Version: 3.0.01744.0001 Branch: .SourceBranch Commit: f3a69a2
# 2021/10/14 18:48:07 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/10/14 18:48:07 Send process info logs to master server succeeded
# 2021/10/14 18:48:07 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/10/14 18:48:07 Send process info logs to master server succeeded
# [2021-10-14T18:48:07.786115] Entering context manager injector.
# [2021-10-14T18:48:08.265113] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['pipeline_data_prepare.py', '--datafolder', '/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/datafolder'])
# Script type = None
# [2021-10-14T18:48:08.268801] Entering Run History Context Manager.
# [2021-10-14T18:48:08.948462] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/wd/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb
# [2021-10-14T18:48:08.948500] Preparing to call script [pipeline_data_prepare.py] with arguments:['--datafolder', '/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/datafolder']
# [2021-10-14T18:48:08.948523] After variable expansion, calling script [pipeline_data_prepare.py] with arguments:['--datafolder', '/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/mounts/workspaceblobstore/azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/datafolder']
#
# 2021/10/14 18:48:12 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#
# [2021-10-14T18:48:18.052823] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.0870656967163086 seconds
# [2021-10-14T18:48:18.240022] Finished context manager injector.
#
# Streaming azureml-logs/75_job_post-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# ===============================================================================================================
# [2021-10-14T18:48:25.846590] Entering job release
# [2021-10-14T18:48:26.745810] Starting job release
# [2021-10-14T18:48:26.746580] Logging experiment finalizing status in history service.
# [2021-10-14T18:48:26.746766] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 325
# [2021-10-14T18:48:26.747642] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-10-14T18:48:26.747943] job release stage : execute_job_release starting...
# [2021-10-14T18:48:26.748561] Entering context manager injector.
# [2021-10-14T18:48:26.748976] job release stage : copy_batchai_cached_logs starting...
# [2021-10-14T18:48:26.749041] job release stage : copy_batchai_cached_logs completed...
# [2021-10-14T18:48:26.777502] job release stage : upload_datastore completed...
# [2021-10-14T18:48:26.922643] job release stage : send_run_telemetry starting...
# [2021-10-14T18:48:26.938345] get vm size and vm region successfully.
# [2021-10-14T18:48:26.945486] get compute meta data successfully.
# [2021-10-14T18:48:26.964040] job release stage : execute_job_release completed...
# [2021-10-14T18:48:27.108113] post artifact meta request successfully.
# [2021-10-14T18:48:27.188125] upload compute record artifact successfully.
# [2021-10-14T18:48:27.188219] job release stage : send_run_telemetry completed...
# [2021-10-14T18:48:27.188760] Job release is complete
#
# StepRun(01 data_preprocessing) Execution Summary
# =================================================
# StepRun( 01 data_preprocessing ) Status: Finished
# ...
# >>>   2021/10/14 18:49:32 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/wd/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/azureml_compute_logs
# >>>   2021/10/14 18:49:32 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_787a1ecd36f533049488c5a225359bf2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/mounts/workspaceblobstore/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5da9547-ebe8-45fb-9402-a9076c771f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/10/14 18:49:32 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/wd/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/azureml_compute_logs/65_job_prep-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:49:32 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/wd/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/azureml_compute_logs/65_job_prep-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# >>>   2021/10/14 18:49:32 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/c3b19f0d-b2a8-482c-b_9cbdbd53-b7f3-49e5-9d0a-60d39e196ec1/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/wd/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032;/azureml-envs/azureml_787a1ecd36f533049488c5a225359bf2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/mounts/workspaceblobstore/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5da9547-ebe8-45fb-9402-a9076c771f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/10/14 18:49:32 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/10/14 18:49:32 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-e7672d18342a62b33aa63e7958506c28-c09ab24ff4fef270-01 -t c3b19f0d-b2a8-482c-b83d-823e3d657032 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/b062aa28-1424-407f-8d89-d7c98c33ee7e/job-1/c3b19f0d-b2a8-482c-b_9cbdbd53-b7f3-49e5-9d0a-60d39e196ec1/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/wd/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032;/azureml-envs/azureml_787a1ecd36f533049488c5a225359bf2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032/mounts/workspaceblobstore/azureml/c3b19f0d-b2a8-482c-b83d-823e3d657032-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5da9547-ebe8-45fb-9402-a9076c771f1d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/10/14 18:49:34 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 2
# >>>   FilteredData: 0.
# >>>   2021/10/14 18:49:37 containerName:c3b19f0d-b2a8-482c-b83d-823e3d657032
# >>>   2021/10/14 18:49:37 sidecar containerName:c3b19f0d-b2a8-482c-b83d-823e3d657032
# >>>   2021/10/14 18:49:37 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/10/14 18:49:37 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:49:37 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:49:37 sidecar dockerLauncher:docker
# >>>   2021/10/14 18:49:37 sidecarContainerId:e19a8c98bae07b31c21eadefb7222c7f3b720ef78ac16f14b523ba6805c1a948
# >>>   2021/10/14 18:49:37 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/10/14 18:49:37 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:49:37 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/10/14 18:49:37 Docker logs for c3b19f0d-b2a8-482c-b83d-823e3d657032
# >>>
# >>>   2021/10/14 18:49:37 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:32.976530] Entering job preparation.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.636740] Starting job preparation.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.636774] Extracting the control code.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.637091] Starting extract_project.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.637167] Starting to extract zip file.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.663792] Finished extracting zip file.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.671955] Using urllib.request Python 3.0 or later
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.672026] Start fetching snapshots.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.672093] Start fetching snapshot.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:34.672112] Retrieving project from snapshot: a5da9547-ebe8-45fb-9402-a9076c771f1d
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 44
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.474386] Finished fetching snapshot.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.474446] Finished fetching snapshots.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.474480] Finished extract_project.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.474582] Finished fetching and extracting the control code.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.479989] downloadDataStore - Download from datastores if requested.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.480520] Start run_history_prep.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.486415] Entering context manager injector.
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: Acquired lockfile /tmp/c3b19f0d-b2a8-482c-b83d-823e3d657032-datastore.lock to downloading input data references
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.954950] downloadDataStore completed
# >>>   2021/10/14 18:49:37 runSpecialJobTask: preparation: [2021-10-14T18:49:36.958353] Job preparation is complete.
# >>>   2021/10/14 18:49:37 DockerSideCarContainerLogs:
# >>>
# >>>   2021/10/14 18:49:37 DockerSideCarContainerLogs End
# >>>   2021/10/14 18:49:37 Execution of runSpecialJobTask completed
# >>>   2021/10/14 18:49:37 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/10/14 18:49:37 Process Exiting with Code:  0
# >>>   2021/10/14 18:49:38 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-10-14T18:49:38Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:49:38Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-14T18:49:38Z 127.0.0.1 slots=2 max-slots=2
# 2021-10-14T18:49:38Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_db31589b9d9c1ad7de24beacc0ad45383e39fc8484a000df02d5d14e478949ec_d.txt
# ===============================================================================================================
# [2021-10-14T18:49:48.306952] Entering job release
# [2021-10-14T18:49:49.176131] Starting job release
# [2021-10-14T18:49:49.177144] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 137
# [2021-10-14T18:49:49.177691] job release stage : upload_datastore starting...
# [2021-10-14T18:49:49.178013] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-10-14T18:49:49.185623] job release stage : execute_job_release starting...
# [2021-10-14T18:49:49.188821] Entering context manager injector.
# [2021-10-14T18:49:49.189953] job release stage : copy_batchai_cached_logs starting...
# [2021-10-14T18:49:49.190415] job release stage : copy_batchai_cached_logs completed...
# [2021-10-14T18:49:49.207758] job release stage : upload_datastore completed...
# [2021-10-14T18:49:49.245981] job release stage : send_run_telemetry starting...
# [2021-10-14T18:49:49.264727] get vm size and vm region successfully.
# [2021-10-14T18:49:49.272352] get compute meta data successfully.
# [2021-10-14T18:49:49.406557] post artifact meta request successfully.
# [2021-10-14T18:49:49.409248] job release stage : execute_job_release completed...
# [2021-10-14T18:49:49.440336] upload compute record artifact successfully.
# [2021-10-14T18:49:49.440390] job release stage : send_run_telemetry completed...
# [2021-10-14T18:49:49.440614] Job release is complete
#
# StepRun(02 model_training) Execution Summary
# =============================================
# StepRun( 02 model_training ) Status: Finished
# {'runId': 'c3b19f0d-b2a8-482c-b83d-823e3d657032', 'target': 'rk-test-compute', 'status': 'Completed', 'startTimeUtc': '2021-10-14T18:48:51.205417Z', 'endTimeUtc': '2021-10-14T18:49:58.075368Z', 'properties': {'ContentSnapshotId': 'a5da9547-ebe8-45fb-9402-a9076c771f1d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'a3b02f09-94e5-499b-8285-41268f060607', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '4e408fd0', 'azureml.pipelinerunid': 'a561e068-8103-4117-9de9-b446ed437b19', 'azureml.pipeline': 'a561e068-8103-4117-9de9-b446ed437b19', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'pipeline_model_training.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--datafolder', '$AZUREML_DATAREFERENCE_datafolder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'rk-test-compute', 'dataReferences': {'datafolder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/9ce9ea22-e38e-4f97-a0b6-f13db77644bb/datafolder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'env_azure_pipeline', 'version': '7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.30.0']}, 'pandas', 'scikit-learn', 'pip'], 'name': 'azureml_787a1ecd36f533049488c5a225359bf2'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1, 'location': None}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': [], 'dataBricks': {'workers': 0, 'minimumWorkerCount': 0, 'maxMumWorkerCount': 0, 'sparkVersion': '4.0.x-scala2.11', 'nodeTypeId': 'Standard_D3_v2', 'sparkConf': {}, 'sparkEnvVars': {}, 'instanc ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'a561e068-8103-4117-9de9-b446ed437b19', 'status': 'Completed', 'startTimeUtc': '2021-10-14T18:43:26.786798Z', 'endTimeUtc': '2021-10-14T18:49:59.013248Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.a561e068-8103-4117-9de9-b446ed437b19/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=eUCeqMQbwaT01U%2BIAl7L4idkHw4GtTkKbq9%2BhsaAeuA%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-14T14%3A18%3A31Z&ske=2021-10-15T22%3A28%3A31Z&sks=b&skv=2019-07-07&st=2021-10-14T18%3A40%3A00Z&se=2021-10-15T02%3A50%3A00Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.a561e068-8103-4117-9de9-b446ed437b19/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=KHxH6C571PiJ3u%2F5bGCS2lDKN5v2WVoIygIlFUPGTow%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-14T14%3A18%3A31Z&ske=2021-10-15T22%3A28%3A31Z&sks=b&skv=2019-07-07&st=2021-10-14T18%3A40%3A00Z&se=2021-10-15T02%3A50%3A00Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.a561e068-8103-4117-9de9-b446ed437b19/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=uu00l917z5gTXt1QYyMHNsWpVhHL1%2BnnTa8QQLO7Bas%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-14T14%3A18%3A31Z&ske=2021-10-15T22%3A28%3A31Z&sks=b&skv=2019-07-07&st=2021-10-14T18%3A40%3A00Z&se=2021-10-15T02%3A50%3A00Z&sp=r'}, 'submittedBy': 'Roshan Koirala'}
# 'Finished'

# %% [markdown]
# # Publish pipeline
#
# We can access the rest endpoint by publishing the pipeline.

# %%
# The pipeline_run here looks same as the running notebook pipeline_run. 
# But this give an error proceeding forward. 
pipeline_exp = ws.experiments.get('azureml-demo-exp')
list(pipeline_exp.get_runs())[0]
# Out:
# Run(Experiment: azureml-demo-exp,
# Id: 79793b8d-4092-4c19-a326-3111c812dfb5,
# Type: azureml.PipelineRun,
# Status: Completed)

# %%
pipeline_run
# Out:
# Run(Experiment: azureml-demo-exp,
# Id: 79793b8d-4092-4c19-a326-3111c812dfb5,
# Type: azureml.PipelineRun,
# Status: Completed)

# %%
published_pipeline = pipeline_run.publish_pipeline(name='training_pipeline', 
                                                   description='Pipeline demo', 
                                                   version='1.0')
published_pipeline
# Out:
# Pipeline(Name: training_pipeline,
# Id: c3f9e3f4-cd08-449d-bf67-602b1b8ceb1e,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourceGroups/rg-dataservices-sandbox-01/providers/Microsoft.MachineLearningServices/workspaces/ds_dev_01/PipelineRuns/PipelineSubmit/c3f9e3f4-cd08-449d-bf67-602b1b8ceb1e)

# %%
rest_endpoint = published_pipeline.endpoint
rest_endpoint
# Out:
# 'https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourceGroups/rg-dataservices-sandbox-01/providers/Microsoft.MachineLearningServices/workspaces/ds_dev_01/PipelineRuns/PipelineSubmit/c3f9e3f4-cd08-449d-bf67-602b1b8ceb1e'

# %%
published_pipeline.id
# Out:
# 'c3f9e3f4-cd08-449d-bf67-602b1b8ceb1e'

# %% [markdown]
# # Using published pipeline

# %%
import requests

response = requests.post(rest_endpoint, 
                        header=auth_header,
                        json={'ExperimentName':'azureml-demo-exp'})
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11124/142667710.py in <module>
#       2
#       3 response = requests.post(rest_endpoint,
# ----> 4                         header=auth_header,
#       5                         json={'ExperimentName':'exp-008'})
#       6 response
#
# NameError: name 'auth_header' is not defined

# %% [markdown]
# # Schedule a pipeline
#
# We can scheule to run a pipeline in a regular interval. This is one of the key step in the deployment through batch inference.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# %%
hourly = ScheduleRecurrence(frequency='Hour', interval=1)
pipeline_schedule = Schedule.create(workspace=ws, 
                                   name='trains model hourly', 
                                   pipeline_id=published_pipeline.id, 
                                   experiment_name='azureml-demo-exp', 
                                   recurrence=hourly)

# %%
pipeline_schedule
# Out:
# Pipeline(Name: trains model hourly,
# Id: adeafe6a-f075-483f-a5f3-af7e5c420354,
# Status: Active,
# Pipeline Id: c3f9e3f4-cd08-449d-bf67-602b1b8ceb1e,
# Pipeline Endpoint Id: None,
# Recurrence Details: Runs every Hour)

# %% [markdown]
# # Disable/Enable schedule

# %%
pipeline_schedule.disable()

# %% [markdown]
# ```pyhton
# pipeline_schedule.disable()
# pipeline_schedule.enable()
# ```

# %% [markdown]
# # Delete compute cluster

# %% [markdown]
# How to delete the cluster between the scheduled run?
#
# ```python
# cluster.delete()
# ```

# %%
rk_cluster.delete()
