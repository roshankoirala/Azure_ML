# %%
from azureml.core import Workspace, Environment, ScriptRunConfig, Experiment 
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# %%
ws = Workspace.from_config()

# %% [markdown]
# # Creating a managed Compute target
#
# We may be interested to use the cloud `Compute` resources for two reasons:
# - For large data and large models local machine is not enough to store and run the computation. For this we can use `compute instances` and/or `compute clusters`.
# - It is natural to use cloud computation for model deployment. For this we use `Inference clusters`.
#
# Here we discuss managing compute target for the first purpose in mind. We discuss managing the compute target for the deployment later.
#
# We use `AmlCompute` object from `azureml-sdk` to provision the computation target.

# %%
compute_name = 'rk-test-compute'

compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', 
                                                       max_nodes=2)

rk_cluster = ComputeTarget.create(ws, compute_name, compute_config)
rk_cluster.wait_for_completion(show_output=True)
# Out:
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# # Check for an existing compute target
#
# Here we can avoide creating additional cluster if it is already exists. For this we use `ComputeTargetException` object.

# %%
try:
    rk_cluster = ComputeTarget(ws, compute_name)
    print('Found existing cluster')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', 
                                                       max_nodes=2)

    rk_cluster = ComputeTarget.create(ws, compute_name, compute_config)
    
rk_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# # Use compute targets
#
# Now we create a vertual environment in the compute target. We can configure a python script to run on the cloud computation target with specified virtual environment using `ScriptRunConfig` object.

# %%
training_env = Environment.get(workspace=ws, 
                               name='training_environment')

script_config = ScriptRunConfig(source_directory='.', 
                               script='script_1.py', 
                               environment=training_env,  # environment specified 
                               compute_target=rk_cluster  # computation target on cloud 
                               )

# %%
# rest of the code is similar to the previous one 
experiment = Experiment(workspace=ws, name='azureml-demo-exp')
run = experiment.submit(config=script_config)
run.wait_for_completion(show_output=True)
# Out:
# RunId: azureml-demo-exp_1633634766_fb3c25e7
# Web View: https://ml.azure.com/runs/azureml-demo-exp_1633634766_fb3c25e7?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/10/07 19:26:13 Downloading source code...
# 2021/10/07 19:26:14 Finished downloading source code
# 2021/10/07 19:26:14 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/10/07 19:26:15 Successfully set up Docker network: acb_default_network
# 2021/10/07 19:26:15 Setting up Docker configuration...
# 2021/10/07 19:26:15 Successfully set up Docker configuration
# 2021/10/07 19:26:15 Logging in to registry: 0319839584634a4d8899cb105b49c173.azurecr.io
# 2021/10/07 19:26:16 Successfully logged into 0319839584634a4d8899cb105b49c173.azurecr.io
# 2021/10/07 19:26:16 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/07 19:26:16 Scanning for dependencies...
# 2021/10/07 19:26:16 Successfully scanned dependencies
# 2021/10/07 19:26:16 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# feac53061382: Pull complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# Digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#  ---> 82e13edbc8db
# Step 2/19 : USER root
#  ---> Running in 72fb05450bef
# Removing intermediate container 72fb05450bef
#  ---> fc261271601f
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in a95dbf6206d8
# Removing intermediate container a95dbf6206d8
#  ---> 0c0d26ba1b0b
# Step 4/19 : WORKDIR /
#  ---> Running in cb5e2ef9144d
# Removing intermediate container cb5e2ef9144d
#  ---> fe6fad2d247c
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 2d8ec87de003
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 4c3055cd1ebb
# Removing intermediate container 4c3055cd1ebb
#  ---> 8ba6ef839583
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> cfe75396013f
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 839a4e68a9a5
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ####       |  40%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# pytz-2021.1          | 181 KB    |            |   0%
# pytz-2021.1          | 181 KB    | ########## | 100%
#
# wheel-0.37.0         | 33 KB     |            |   0%
# wheel-0.37.0         | 33 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 7          |   7%
# mkl-2020.2           | 138.3 MB  | #8         |  18%
# mkl-2020.2           | 138.3 MB  | ##8        |  29%
# mkl-2020.2           | 138.3 MB  | ###9       |  40%
# mkl-2020.2           | 138.3 MB  | ####8      |  49%
# mkl-2020.2           | 138.3 MB  | #####9     |  60%
# mkl-2020.2           | 138.3 MB  | #######    |  70%
# mkl-2020.2           | 138.3 MB  | ########   |  81%
# mkl-2020.2           | 138.3 MB  | #########1 |  91%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# ca-certificates-2021 | 113 KB    |            |   0%
# ca-certificates-2021 | 113 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ####       |  40%
# python-3.6.2         | 23.6 MB   | ########## | 100%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# intel-openmp-2021.3. | 1.4 MB    |            |   0%
# intel-openmp-2021.3. | 1.4 MB    | ########## | 100%
#
# pandas-1.1.5         | 8.2 MB    |            |   0%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.34.0-py3-none-any.whl (3.1 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.34.0
#   Downloading azureml_dataset_runtime-1.34.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-inference-server-http~=0.3.1
#   Downloading azureml_inference_server_http-0.3.2-py3-none-any.whl (38 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting azureml-core~=1.34.0
#   Downloading azureml_core-1.34.0-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt (line 1)) (58.0.4)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.2-py2.py3-none-any.whl (145 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt (line 1)) (2.8.2)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt (line 1)) (2021.1)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.2.0-py3-none-any.whl (16 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.19.0-py2.py3-none-any.whl (176 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt (line 1)) (1.16.0)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.23.0a,>=2.22.0a
#   Downloading azureml_dataprep-2.22.2-py3-none-any.whl (39.4 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt (line 1)) (1.19.2)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex~=1.20.0dev0
#   Downloading azureml_dataprep_rslex-1.20.2-cp36-cp36m-manylinux1_x86_64.whl (10.9 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.15.0-py2.py3-none-any.whl (77 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uxmyuo2c.requirements.txt (line 1)) (2021.5.30)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.1.0-py2.py3-none-any.whl (94 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.3.0-py2.py3-none-any.whl (154 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.18.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=0a7820292d2f757167905ed89ad71940e00377bff1a1bd5c29acf30b74beee29
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=ca5b80ee8da4e7c7a1b7ab4b9e8371b2dd71ebb0be18bb31ff167c003041f151
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69942 sha256=66dca87238a2b74d38d0d39ff34bbf408aae22444463d6995e93abbecbb096a9
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=1f3ca3b1a95534ad096fd632dd856ed372462983f35c381edd2b3f0f2294defc
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, typing-extensions, pyasn1, portalocker, oauthlib, msal, zipp, rsa, requests-oauthlib, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, msrest, MarkupSafe, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, werkzeug, websocket-client, ruamel.yaml.clib, pyopenssl, pyarrow, opencensus-context, msrestazure, Jinja2, jeepney, itsdangerous, google-api-core, click, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, jsonpickle, jmespath, inference-schema, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, opencensus-ext-azure, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.2 MarkupSafe-2.0.1 PyJWT-2.2.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.19.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.34.0 azureml-dataprep-2.22.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.20.2 azureml-dataset-runtime-1.34.0 azureml-defaults-1.34.0 azureml-inference-server-http-0.3.2 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.4 cffi-1.14.6 charset-normalizer-2.0.6 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-5.0.2 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 google-api-core-2.1.0 google-auth-2.3.0 googleapis-common-protos-1.53.0 gunicorn-20.1.0 idna-3.2 immutables-0.16 importlib-metadata-4.8.1 inference-schema-1.3.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.15.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 opencensus-0.8.0 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.18.1 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.6 websocket-client-1.2.1 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 839a4e68a9a5
#  ---> a11d0d325c63
# Step 9/19 : ENV PATH /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/bin:$PATH
#  ---> Running in c66891e5f7b0
# Removing intermediate container c66891e5f7b0
#  ---> 7dd02d3a1156
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 57e5d725aafc
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 599b3ea8bb5d
# Copying environment context
# Removing intermediate container 599b3ea8bb5d
#  ---> aef6153e1025
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 8321fc47adeb
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495
#  ---> Running in 9f9912bb654d
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 9f9912bb654d
#  ---> 47dfdaea4ccc
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495
#  ---> Running in 4a73d39d8d34
# Removing intermediate container 4a73d39d8d34
#  ---> f559b575b9f5
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib:$LD_LIBRARY_PATH
#  ---> Running in c87509e58a1b
# Removing intermediate container c87509e58a1b
#  ---> de84386b6e5c
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 7b6c44d01437
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 4ef3427a12f9
# Removing intermediate container 4ef3427a12f9
#  ---> a64078c82aed
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in ee928963c5d2
# Removing intermediate container ee928963c5d2
#  ---> b17e3daae91a
# Step 19/19 : CMD ["bash"]
#  ---> Running in aac79edef495
# Removing intermediate container aac79edef495
#  ---> d557855a18ed
# Successfully built d557855a18ed
# Successfully tagged 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest
# Successfully tagged 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:1
# 2021/10/07 19:28:04 Successfully executed container: acb_step_0
# 2021/10/07 19:28:04 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/07 19:28:04 Pushing image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:1, attempt 1
# The push refers to repository [0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9]
# cb529846d2f4: Preparing
# 558eb1bc876e: Preparing
# fe04b3451168: Preparing
# 7d567d7c86c4: Preparing
# 20d4bfbbb917: Preparing
# a79238dbcc50: Preparing
# 0e1a00eca057: Preparing
# d0ad24614f17: Preparing
# 7e3c43c8715b: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# a79238dbcc50: Waiting
# 0e1a00eca057: Waiting
# d0ad24614f17: Waiting
# 7e3c43c8715b: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# 7d567d7c86c4: Pushed
# fe04b3451168: Pushed
# cb529846d2f4: Pushed
# 558eb1bc876e: Pushed
# 0e1a00eca057: Pushed
# a79238dbcc50: Pushed
# d0ad24614f17: Pushed
# 7e3c43c8715b: Pushed
# 9398792c8299: Pushed
# 93c9ec44fed0: Pushed
# e0ae5bb40eae: Pushed
# 5e9c7e64af11: Pushed
# 94c0f7816c07: Pushed
# accea658c5be: Pushed
# 21639b09744f: Pushed
# c96f19f3c075: Pushed
# 20e11b7f408c: Pushed
#
# 20d4bfbbb917: Pushed
# 1: digest: sha256:8f5a66154fbcc68835d889d26e025a92678ddcd1e617ff56bb1faad361b7009e size: 4099
# 2021/10/07 19:29:36 Successfully pushed image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:1
# 2021/10/07 19:29:36 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/07 19:29:36 Pushing image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest, attempt 1
# The push refers to repository [0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9]
# cb529846d2f4: Preparing
# 558eb1bc876e: Preparing
# fe04b3451168: Preparing
# 7d567d7c86c4: Preparing
# 20d4bfbbb917: Preparing
# a79238dbcc50: Preparing
# 0e1a00eca057: Preparing
# d0ad24614f17: Preparing
# 7e3c43c8715b: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# a79238dbcc50: Waiting
# 0e1a00eca057: Waiting
# d0ad24614f17: Waiting
# 7e3c43c8715b: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# cb529846d2f4: Layer already exists
# 558eb1bc876e: Layer already exists
# fe04b3451168: Layer already exists
# 7d567d7c86c4: Layer already exists
# 0e1a00eca057: Layer already exists
# 7e3c43c8715b: Layer already exists
# d0ad24614f17: Layer already exists
# a79238dbcc50: Layer already exists
# 9398792c8299: Layer already exists
# 5e9c7e64af11: Layer already exists
# 93c9ec44fed0: Layer already exists
# 20e11b7f408c: Layer already exists
# e0ae5bb40eae: Layer already exists
# 94c0f7816c07: Layer already exists
# accea658c5be: Layer already exists
# c96f19f3c075: Layer already exists
# 21639b09744f: Layer already exists
# 20d4bfbbb917: Layer already exists
# latest: digest: sha256:8f5a66154fbcc68835d889d26e025a92678ddcd1e617ff56bb1faad361b7009e size: 4099
# 2021/10/07 19:29:39 Successfully pushed image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest
# 2021/10/07 19:29:39 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 107.895859)
# 2021/10/07 19:29:39 Populating digests for step ID: acb_step_0...
# 2021/10/07 19:29:40 Successfully populated digests for step ID: acb_step_0
# 2021/10/07 19:29:40 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 92.434099)
# 2021/10/07 19:29:40 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.301203)
# 2021/10/07 19:29:40 The following dependencies were found:
# 2021/10/07 19:29:40
# - image:
#     registry: 0319839584634a4d8899cb105b49c173.azurecr.io
#     repository: azureml/azureml_0264f45ad22a89df2f6eff9450470de9
#     tag: latest
#     digest: sha256:8f5a66154fbcc68835d889d26e025a92678ddcd1e617ff56bb1faad361b7009e
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
# - image:
#     registry: 0319839584634a4d8899cb105b49c173.azurecr.io
#     repository: azureml/azureml_0264f45ad22a89df2f6eff9450470de9
#     tag: "1"
#     digest: sha256:8f5a66154fbcc68835d889d26e025a92678ddcd1e617ff56bb1faad361b7009e
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
#
#
# Run ID: ch4 was successful after 3m28s
# Streaming azureml-logs/55_azureml-execution-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt
# ========================================================================================================================
#
# 2021-10-07T19:35:23Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/azureml-demo-exp_1633634766_fb3c25e7/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/azureml-demo-exp_1633634766_fb3c25e7/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24782 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/azureml-demo-exp_1633634766_fb3c25e7/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-07T19:35:23Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/azureml-demo-exp_1633634766_fb3c25e7/mounts/workspaceblobstore
# 2021-10-07T19:35:23Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-07T19:35:23Z Starting output-watcher...
# 2021-10-07T19:35:23Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-10-07T19:35:23Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-10-07T19:35:23Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_0264f45ad22a89df2f6eff9450470de9
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# 18c7628ee319: Pulling fs layer
# 68daf40fbbda: Pulling fs layer
# 784cd795e148: Pulling fs layer
# 0d80ec178ef7: Pulling fs layer
# 150b7d7cf814: Pulling fs layer
# 6d155d2bfbb0: Pulling fs layer
# 3f61aac2d354: Pulling fs layer
# ff8d694b1507: Pulling fs layer
# 70522b1cd5fd: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# 18c7628ee319: Waiting
# 68daf40fbbda: Waiting
# 784cd795e148: Waiting
# 0d80ec178ef7: Waiting
# 150b7d7cf814: Waiting
# 3f61aac2d354: Waiting
# ff8d694b1507: Waiting
# 70522b1cd5fd: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# feac53061382: Pull complete
# 18c7628ee319: Verifying Checksum
# 18c7628ee319: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# 68daf40fbbda: Verifying Checksum
# 68daf40fbbda: Download complete
# 784cd795e148: Download complete
# 0d80ec178ef7: Verifying Checksum
# 0d80ec178ef7: Download complete
# 6d155d2bfbb0: Verifying Checksum
# 6d155d2bfbb0: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# 3f61aac2d354: Verifying Checksum
# 3f61aac2d354: Download complete
# 70522b1cd5fd: Verifying Checksum
# 70522b1cd5fd: Download complete
# ff8d694b1507: Verifying Checksum
# ff8d694b1507: Download complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# 150b7d7cf814: Verifying Checksum
# 150b7d7cf814: Download complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# 18c7628ee319: Pull complete
# 68daf40fbbda: Pull complete
# 784cd795e148: Pull complete
# 0d80ec178ef7: Pull complete
#
# Streaming azureml-logs/75_job_post-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt
# ===============================================================================================================
#
# [2021-10-07T19:36:12.874752] Entering job release
# [2021-10-07T19:36:13.631565] Starting job release
# [2021-10-07T19:36:13.632355] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 136
# [2021-10-07T19:36:13.632901] job release stage : upload_datastore starting...
# [2021-10-07T19:36:13.633898] Entering context manager injector.
# [2021-10-07T19:36:13.636216] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-10-07T19:36:13.642974] job release stage : upload_datastore completed...
# [2021-10-07T19:36:13.643062] job release stage : execute_job_release starting...
# [2021-10-07T19:36:13.643995] job release stage : copy_batchai_cached_logs starting...
# [2021-10-07T19:36:13.644220] job release stage : copy_batchai_cached_logs completed...
# [2021-10-07T19:36:13.745075] job release stage : send_run_telemetry starting...
# [2021-10-07T19:36:13.787495] get vm size and vm region successfully.
# [2021-10-07T19:36:13.794279] get compute meta data successfully.
# [2021-10-07T19:36:13.833036] job release stage : execute_job_release completed...
# [2021-10-07T19:36:13.929348] post artifact meta request successfully.
# [2021-10-07T19:36:13.962883] upload compute record artifact successfully.
# [2021-10-07T19:36:13.963001] job release stage : send_run_telemetry completed...
# [2021-10-07T19:36:13.963406] Job release is complete
#
# Execution Summary
# =================
# RunId: azureml-demo-exp_1633634766_fb3c25e7
# Web View: https://ml.azure.com/runs/azureml-demo-exp_1633634766_fb3c25e7?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# {'runId': 'azureml-demo-exp_1633634766_fb3c25e7',
#  'target': 'rk-test-compute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-10-07T19:35:20.748548Z',
#  'endTimeUtc': '2021-10-07T19:36:22.171693Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'ebde9b4e-a404-453b-9931-f7acb696aa1c',
#   'azureml.git.repository_uri': 'https://github.com/roshankoirala/MLOps.git',
#   'mlflow.source.git.repoURL': 'https://github.com/roshankoirala/MLOps.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'cf58f46e4a0bde9e6012ad78d77de1497aa012ce',
#   'mlflow.source.git.commit': 'cf58f46e4a0bde9e6012ad78d77de1497aa012ce',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'script_1.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'rk-test-compute',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'training_environment',
#    'version': '1',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'dependencies': ['pandas',
#       'scikit-learn',
#       {'pip': ['azureml-defaults']},
#       'python=3.6.2'],
#      'name': 'azureml_63f39e4ec1a88630ccbd9626dd1e7495'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None,
#    'location': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=L9jenQidgeJQjHOnan%2F3sXdWqSFCLMTHgPxuAUAK40k%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/55_azureml-execution-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt?sv=2019-07-07&sr=b&sig=5kt2TagOS8dEptdT4HJ6sbJkCMtSrVlhryWtf4UeAL8%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/65_job_prep-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt?sv=2019-07-07&sr=b&sig=6DfiP4sCgmN90Dmp54JsbtNwPkNZoVsHbvCkUMGJH1M%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=ePPrwGGzLooeVdS787NDTE8SVFJjibkW9c%2FmzBySZok%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/75_job_post-tvmps_d616799ab6c5e0c7f4a2fc8326de22680b55a0e5aaa1e2a74e3aecdd67c24324_d.txt?sv=2019-07-07&sr=b&sig=2wbaBSxUg9wQjthG37eWO40XHzTVxRG72HU1gwtQIaM%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'azureml-logs/process_info.json': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/process_info.json?sv=2019-07-07&sr=b&sig=4qVh46dtC5okIHniBaiTEkL0tnjLZb%2FqIo7gcFSiqTE%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'azureml-logs/process_status.json': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/azureml-logs/process_status.json?sv=2019-07-07&sr=b&sig=YBozBAdehZqiFAHK9vEHuIhZ9NWcuwwz2Yk5P84lfSg%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'logs/azureml/93_azureml.log': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/logs/azureml/93_azureml.log?sv=2019-07-07&sr=b&sig=RdUdI7qJdo0YD63r031b68wMnFLMiTduYYTkh9UPVeY%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/logs/azureml/job_prep_azureml.log?sv=2019-07-07&sr=b&sig=g9G%2B972dBhPRJImLeYA3Bun40DtD4CeLucdKLtZnwDY%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://dsdev011073180542.blob.core.windows.net/azureml/ExperimentRun/dcid.azureml-demo-exp_1633634766_fb3c25e7/logs/azureml/job_release_azureml.log?sv=2019-07-07&sr=b&sig=Xbeo%2BXkGTOPJgPEBsNhDR1Mqh00Ya%2BeLTQWWPO4VZgw%3D&skoid=b14fb336-66cf-43ab-a99a-2949dab01787&sktid=4ef6e02a-f252-4618-a1dc-03bd2f93157d&skt=2021-10-07T13%3A36%3A38Z&ske=2021-10-08T21%3A46%3A38Z&sks=b&skv=2019-07-07&st=2021-10-07T19%3A26%3A39Z&se=2021-10-08T03%3A36%3A39Z&sp=r'},
#  'submittedBy': 'Roshan Koirala'}

# %% [markdown]
# # Delete compute cluster
#
# `Compute` resources on the cloud are one of the most expensive one. So after the use it is good idea to delete the cluster. We may also stop but it may charge some money still.

# %%
rk_cluster.delete()
