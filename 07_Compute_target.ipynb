# %%
from azureml.core import Workspace, Environment, ScriptRunConfig, Experiment 
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# %%
ws = Workspace.from_config()

# %% [markdown]
# # Creating a managed Compute target
#
# We may be interested to use the cloud `Compute` resources for two reasons:
# - For large data and large models local machine is not enough to store and run the computation. For this we can use `compute instances` and/or `compute clusters`.
# - It is natural to use cloud computation for model deployment. For this we use `Inference clusters`.
#
# Here we discuss managing compute target for the first purpose in mind. We discuss managing the compute target for the deployment later.
#
# We use `AmlCompute` object from `azureml-sdk` to provision the computation target.

# %%
compute_name = 'rk-test-compute'

compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', 
                                                       max_nodes=2)

rk_cluster = ComputeTarget.create(ws, compute_name, compute_config)
rk_cluster.wait_for_completion(show_output=True)
# Out:
# InProgress...
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# # Check for an existing compute target
#
# Here we can avoide creating additional cluster if it is already exists. For this we use `ComputeTargetException` object.

# %%
try:
    rk_cluster = ComputeTarget(ws, compute_name)
    print('Found existing cluster')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', 
                                                       max_nodes=2)

    rk_cluster = ComputeTarget.create(ws, compute_name, compute_config)
    
rk_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# # Use compute targets
#
# Now we create a vertual environment in the compute target. We can configure a python script to run on the cloud computation target with specified virtual environment using `ScriptRunConfig` object.

# %%
training_env = Environment.get(workspace=ws, 
                               name='training_environment')

script_config = ScriptRunConfig(source_directory='.', 
                               script='experiment_1.py', 
                               environment=training_env,  # environment specified 
                               compute_target=rk_cluster  # computation target on cloud 
                               )

# %%
# rest of the code is similar to the previous one 
experiment = Experiment(workspace=ws, name='exp-007')
run = experiment.submit(config=script_config)
run.wait_for_completion(show_output=True)
# Out:
# RunId: exp-007_1633455195_d27edee9
# Web View: https://ml.azure.com/runs/exp-007_1633455195_d27edee9?wsid=/subscriptions/038a8790-7ab1-483b-abba-30f101e8dcce/resourcegroups/aml-resources-mstutorial/workspaces/aml-mstutorial&tid=68fda48c-5b34-479d-91f9-034da6f0efe3
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/10/05 17:33:21 Downloading source code...
# 2021/10/05 17:33:22 Finished downloading source code
# 2021/10/05 17:33:22 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/10/05 17:33:22 Successfully set up Docker network: acb_default_network
# 2021/10/05 17:33:22 Setting up Docker configuration...
# 2021/10/05 17:33:23 Successfully set up Docker configuration
# 2021/10/05 17:33:23 Logging in to registry: 2c139677d5ec4bce96b537848a4e6382.azurecr.io
# 2021/10/05 17:33:24 Successfully logged into 2c139677d5ec4bce96b537848a4e6382.azurecr.io
# 2021/10/05 17:33:24 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/05 17:33:24 Scanning for dependencies...
# 2021/10/05 17:33:24 Successfully scanned dependencies
# 2021/10/05 17:33:24 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# feac53061382: Pull complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# Digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#  ---> 82e13edbc8db
# Step 2/19 : USER root
#  ---> Running in 861ae5f2ea14
# Removing intermediate container 861ae5f2ea14
#  ---> 9751a6f6a78b
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in a23a3e70928c
# Removing intermediate container a23a3e70928c
#  ---> 7bb7d91816b7
# Step 4/19 : WORKDIR /
#  ---> Running in 23a93fe560fd
# Removing intermediate container 23a93fe560fd
#  ---> bbcd75fb6dd7
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> a6ecb8797020
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 86d7cedb4283
# Removing intermediate container 86d7cedb4283
#  ---> c7625feecdaf
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> e84dc0daa67c
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in f41be5050fba
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pytz-2021.1          | 181 KB    |            |   0%
# pytz-2021.1          | 181 KB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ####3      |  44%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# ca-certificates-2021 | 113 KB    |            |   0%
# ca-certificates-2021 | 113 KB    | ########## | 100%
#
# wheel-0.37.0         | 33 KB     |            |   0%
# wheel-0.37.0         | 33 KB     | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# intel-openmp-2021.3. | 1.4 MB    |            |   0%
# intel-openmp-2021.3. | 1.4 MB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# pandas-1.1.5         | 8.2 MB    |            |   0%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 5          |   5%
# mkl-2020.2           | 138.3 MB  | #3         |  14%
# mkl-2020.2           | 138.3 MB  | ##2        |  22%
# mkl-2020.2           | 138.3 MB  | ###        |  30%
# mkl-2020.2           | 138.3 MB  | ###8       |  39%
# mkl-2020.2           | 138.3 MB  | ####6      |  46%
# mkl-2020.2           | 138.3 MB  | #####3     |  54%
# mkl-2020.2           | 138.3 MB  | ######     |  61%
# mkl-2020.2           | 138.3 MB  | ######9    |  70%
# mkl-2020.2           | 138.3 MB  | #######8   |  79%
# mkl-2020.2           | 138.3 MB  | ########6  |  87%
# mkl-2020.2           | 138.3 MB  | #########4 |  95%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ##6        |  26%
# python-3.6.2         | 23.6 MB   | ######6    |  67%
# python-3.6.2         | 23.6 MB   | #########8 |  98%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.igg2etsp.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.34.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.34.0
#   Downloading azureml_dataset_runtime-1.34.0-py3-none-any.whl (3.5 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting azureml-inference-server-http~=0.3.1
#   Downloading azureml_inference_server_http-0.3.2-py3-none-any.whl (38 kB)
# Collecting azureml-core~=1.34.0
#   Downloading azureml_core-1.34.0-py3-none-any.whl (2.2 MB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.igg2etsp.requirements.txt (line 1)) (58.0.4)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.2-py2.py3-none-any.whl (145 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.igg2etsp.requirements.txt (line 1)) (2021.1)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.igg2etsp.requirements.txt (line 1)) (2.8.2)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.19.0-py2.py3-none-any.whl (176 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.igg2etsp.requirements.txt (line 1)) (1.16.0)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.23.0a,>=2.22.0a
#   Downloading azureml_dataprep-2.22.2-py3-none-any.whl (39.4 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.igg2etsp.requirements.txt (line 1)) (1.19.2)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex~=1.20.0dev0
#   Downloading azureml_dataprep_rslex-1.20.2-cp36-cp36m-manylinux1_x86_64.whl (10.9 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.15.0-py2.py3-none-any.whl (77 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.34.0->azureml-defaults->-r /azureml-environment-setup/condaenv.igg2etsp.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.0.1-py2.py3-none-any.whl (92 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.18.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.2.1-py2.py3-none-any.whl (153 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=647e010db15035884b8517eba131f6b2dc0cf248a7511ae49f151e23d70d5ba9
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=2afc8702d36bfa18d89294c39783debeafedb68a9e939f6fc1fde61a7787e9e4
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69942 sha256=7d64cb9285256e323e422308907694a61b313c5b418a1524335e71e107ffbd2f
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=a517b014cf6147592338eb6f0f0ba584c2be20f5243fe60c2b9e57fd1a5e01dc
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, typing-extensions, pyasn1, portalocker, oauthlib, msal, zipp, rsa, requests-oauthlib, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, msrest, MarkupSafe, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, werkzeug, websocket-client, ruamel.yaml.clib, pyopenssl, pyarrow, opencensus-context, msrestazure, Jinja2, jeepney, itsdangerous, google-api-core, click, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, jsonpickle, jmespath, inference-schema, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, opencensus-ext-azure, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.2 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.19.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.34.0 azureml-dataprep-2.22.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.20.2 azureml-dataset-runtime-1.34.0 azureml-defaults-1.34.0 azureml-inference-server-http-0.3.2 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.4 cffi-1.14.6 charset-normalizer-2.0.6 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-5.0.2 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 google-api-core-2.0.1 google-auth-2.2.1 googleapis-common-protos-1.53.0 gunicorn-20.1.0 idna-3.2 immutables-0.16 importlib-metadata-4.8.1 inference-schema-1.3.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.15.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 opencensus-0.8.0 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.18.0 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.6 websocket-client-1.2.1 werkzeug-1.0.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container f41be5050fba
#  ---> 42b3d214813c
# Step 9/19 : ENV PATH /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/bin:$PATH
#  ---> Running in c90bb1c433c5
# Removing intermediate container c90bb1c433c5
#  ---> 940296b8fb83
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> ab5f1599d40b
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 4a1ca81f4d3b
# Copying environment context
# Removing intermediate container 4a1ca81f4d3b
#  ---> 2cbb974f0787
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 97f1f9e67c3e
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495
#  ---> Running in c70fc219b30f
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container c70fc219b30f
#  ---> d0cb9b83454c
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495
#  ---> Running in 4dbd63457656
# Removing intermediate container 4dbd63457656
#  ---> 630c4911d47f
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_63f39e4ec1a88630ccbd9626dd1e7495/lib:$LD_LIBRARY_PATH
#  ---> Running in a90b763fce3b
# Removing intermediate container a90b763fce3b
#  ---> 315043cece4f
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 64174afad203
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 7326c647ca56
# Removing intermediate container 7326c647ca56
#  ---> cbfef77a8e1b
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 4d1fa7362c24
# Removing intermediate container 4d1fa7362c24
#  ---> 9135e572b0db
# Step 19/19 : CMD ["bash"]
#  ---> Running in 7f0ef6b58140
# Removing intermediate container 7f0ef6b58140
#  ---> 6e107d0f7138
# Successfully built 6e107d0f7138
# Successfully tagged 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest
# Successfully tagged 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:1
# 2021/10/05 17:35:08 Successfully executed container: acb_step_0
# 2021/10/05 17:35:08 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/05 17:35:08 Pushing image: 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:1, attempt 1
# The push refers to repository [2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9]
# 2ea890ecd96e: Preparing
# 904cc09b6ef9: Preparing
# 6b06a3f23ba3: Preparing
# 75eef531f8d3: Preparing
# 617099fc2091: Preparing
# c10b98598e27: Preparing
# c3fdb4618581: Preparing
# abf6050cf517: Preparing
# 6cfdd4f7aa1b: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# c10b98598e27: Waiting
# c3fdb4618581: Waiting
# abf6050cf517: Waiting
# 6cfdd4f7aa1b: Waiting
# 2ea890ecd96e: Pushed
# 6b06a3f23ba3: Pushed
# 75eef531f8d3: Pushed
# 904cc09b6ef9: Pushed
# c10b98598e27: Pushed
# c3fdb4618581: Pushed
# abf6050cf517: Pushed
# 6cfdd4f7aa1b: Pushed
# 9398792c8299: Pushed
# 93c9ec44fed0: Pushed
# 5e9c7e64af11: Pushed
# e0ae5bb40eae: Pushed
# 94c0f7816c07: Pushed
# accea658c5be: Pushed
# 21639b09744f: Pushed
# 20e11b7f408c: Pushed
# c96f19f3c075: Pushed
# 617099fc2091: Pushed
# 1: digest: sha256:544891c49a3ba8c382e1eb85e45ab3a91f4dd8ee005750dd7ba40b2aacb59e47 size: 4099
# 2021/10/05 17:36:35 Successfully pushed image: 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:1
# 2021/10/05 17:36:35 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/05 17:36:35 Pushing image: 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest, attempt 1
# The push refers to repository [2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9]
# 2ea890ecd96e: Preparing
# 904cc09b6ef9: Preparing
# 6b06a3f23ba3: Preparing
# 75eef531f8d3: Preparing
# 617099fc2091: Preparing
# c10b98598e27: Preparing
# c3fdb4618581: Preparing
# abf6050cf517: Preparing
# 6cfdd4f7aa1b: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# c10b98598e27: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c3fdb4618581: Waiting
# abf6050cf517: Waiting
# 6cfdd4f7aa1b: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# 21639b09744f: Waiting
# 75eef531f8d3: Layer already exists
# 904cc09b6ef9: Layer already exists
# 617099fc2091: Layer already exists
# 2ea890ecd96e: Layer already exists
# 6b06a3f23ba3: Layer already exists
# abf6050cf517: Layer already exists
# c3fdb4618581: Layer already exists
# 6cfdd4f7aa1b: Layer already exists
# c10b98598e27: Layer already exists
# 9398792c8299: Layer already exists
# 93c9ec44fed0: Layer already exists
# 20e11b7f408c: Layer already exists
# e0ae5bb40eae: Layer already exists
# 5e9c7e64af11: Layer already exists
# 94c0f7816c07: Layer already exists
# accea658c5be: Layer already exists
# 21639b09744f: Layer already exists
# c96f19f3c075: Layer already exists
# latest: digest: sha256:544891c49a3ba8c382e1eb85e45ab3a91f4dd8ee005750dd7ba40b2aacb59e47 size: 4099
# 2021/10/05 17:36:36 Successfully pushed image: 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest
# 2021/10/05 17:36:36 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 104.722392)
# 2021/10/05 17:36:36 Populating digests for step ID: acb_step_0...
# 2021/10/05 17:36:37 Successfully populated digests for step ID: acb_step_0
# 2021/10/05 17:36:37 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 86.666063)
# 2021/10/05 17:36:37 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.095353)
# 2021/10/05 17:36:37 The following dependencies were found:
# 2021/10/05 17:36:37
# - image:
#     registry: 2c139677d5ec4bce96b537848a4e6382.azurecr.io
#     repository: azureml/azureml_0264f45ad22a89df2f6eff9450470de9
#     tag: latest
#     digest: sha256:544891c49a3ba8c382e1eb85e45ab3a91f4dd8ee005750dd7ba40b2aacb59e47
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
# - image:
#     registry: 2c139677d5ec4bce96b537848a4e6382.azurecr.io
#     repository: azureml/azureml_0264f45ad22a89df2f6eff9450470de9
#     tag: "1"
#     digest: sha256:544891c49a3ba8c382e1eb85e45ab3a91f4dd8ee005750dd7ba40b2aacb59e47
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
#
#
# Run ID: ca2 was successful after 3m17s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt
# ========================================================================================================================
#
# 2021-10-05T17:42:34Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/aml-mstutorial/azureml/exp-007_1633455195_d27edee9/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/aml-mstutorial/azureml/exp-007_1633455195_d27edee9/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24782 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/aml-mstutorial/azureml/exp-007_1633455195_d27edee9/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-05T17:42:34Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aml-mstutorial/azureml/exp-007_1633455195_d27edee9/mounts/workspaceblobstore
# 2021-10-05T17:42:34Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-05T17:42:34Z Starting output-watcher...
# 2021-10-05T17:42:34Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-10-05T17:42:43Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-10-05T17:42:43Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_0264f45ad22a89df2f6eff9450470de9
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# 985a7f581e74: Pulling fs layer
# 45a77754b119: Pulling fs layer
# 00fc5be7a77c: Pulling fs layer
# 76efe3ffdf39: Pulling fs layer
# 371bab6627e6: Pulling fs layer
# 048d9684c2cc: Pulling fs layer
# ff7aa8dcb097: Pulling fs layer
# c0d90deb472b: Pulling fs layer
# 971f26f260e4: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 985a7f581e74: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# 45a77754b119: Waiting
# 048d9684c2cc: Waiting
# ff7aa8dcb097: Waiting
# c0d90deb472b: Waiting
# 00fc5be7a77c: Waiting
# 76efe3ffdf39: Waiting
# 971f26f260e4: Waiting
# 371bab6627e6: Waiting
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# 985a7f581e74: Verifying Checksum
# 985a7f581e74: Download complete
# 45a77754b119: Verifying Checksum
# 45a77754b119: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# 76efe3ffdf39: Verifying Checksum
# 76efe3ffdf39: Download complete
# 00fc5be7a77c: Download complete
# 048d9684c2cc: Verifying Checksum
# 048d9684c2cc: Download complete
# ff7aa8dcb097: Verifying Checksum
# ff7aa8dcb097: Download complete
# 971f26f260e4: Verifying Checksum
# 971f26f260e4: Download complete
# feac53061382: Pull complete
# c0d90deb472b: Verifying Checksum
# c0d90deb472b: Download complete
# 371bab6627e6: Verifying Checksum
# 371bab6627e6: Download complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# 985a7f581e74: Pull complete
# 45a77754b119: Pull complete
# 00fc5be7a77c: Pull complete
# 76efe3ffdf39: Pull complete
# 371bab6627e6: Pull complete
# 048d9684c2cc: Pull complete
# ff7aa8dcb097: Pull complete
# c0d90deb472b: Pull complete
# 971f26f260e4: Pull complete
# Digest: sha256:544891c49a3ba8c382e1eb85e45ab3a91f4dd8ee005750dd7ba40b2aacb59e47
# Status: Downloaded newer image for 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest
# 2c139677d5ec4bce96b537848a4e6382.azurecr.io/azureml/azureml_0264f45ad22a89df2f6eff9450470de9:latest
# 2021-10-05T17:43:21Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-05T17:43:21Z Check if container exp-007_1633455195_d27edee9 already exist exited with 0,
# Streaming azureml-logs/75_job_post-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt
# ===============================================================================================================
#
# [2021-10-05T17:43:42.609793] Entering job release
# [2021-10-05T17:43:43.623143] Starting job release
# [2021-10-05T17:43:43.623681] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 137
# [2021-10-05T17:43:43.624145] job release stage : upload_datastore starting...
# [2021-10-05T17:43:43.633320] Entering context manager injector.
# [2021-10-05T17:43:43.633914] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-10-05T17:43:43.635292] job release stage : upload_datastore completed...
# [2021-10-05T17:43:43.635715] job release stage : execute_job_release starting...
# [2021-10-05T17:43:43.636216] job release stage : copy_batchai_cached_logs starting...
# [2021-10-05T17:43:43.636852] job release stage : copy_batchai_cached_logs completed...
# [2021-10-05T17:43:43.739741] job release stage : send_run_telemetry starting...
# [2021-10-05T17:43:43.781215] get vm size and vm region successfully.
# [2021-10-05T17:43:43.796361] get compute meta data successfully.
# [2021-10-05T17:43:43.909958] job release stage : execute_job_release completed...
# [2021-10-05T17:43:44.016965] post artifact meta request successfully.
# [2021-10-05T17:43:44.050930] upload compute record artifact successfully.
# [2021-10-05T17:43:44.051124] job release stage : send_run_telemetry completed...
# [2021-10-05T17:43:44.051451] Job release is complete
#
# Execution Summary
# =================
# RunId: exp-007_1633455195_d27edee9
# Web View: https://ml.azure.com/runs/exp-007_1633455195_d27edee9?wsid=/subscriptions/038a8790-7ab1-483b-abba-30f101e8dcce/resourcegroups/aml-resources-mstutorial/workspaces/aml-mstutorial&tid=68fda48c-5b34-479d-91f9-034da6f0efe3
# {'runId': 'exp-007_1633455195_d27edee9',
#  'target': 'rk-test-compute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-10-05T17:42:33.094364Z',
#  'endTimeUtc': '2021-10-05T17:43:57.720247Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '07e5aafc-ab2a-4420-91b3-706b0e611f05',
#   'azureml.git.repository_uri': 'https://github.com/roshankoirala/MLOps.git',
#   'mlflow.source.git.repoURL': 'https://github.com/roshankoirala/MLOps.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'experiment_1.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'rk-test-compute',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'training_environment',
#    'version': '2',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'dependencies': ['pandas',
#       'scikit-learn',
#       {'pip': ['azureml-defaults']},
#       'python=3.6.2'],
#      'name': 'azureml_63f39e4ec1a88630ccbd9626dd1e7495'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None,
#    'location': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=RdNu7CV2AWHCXRFTfsMZ%2FBfY%2Bgcf0GQcU44GlX6dEgw%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/55_azureml-execution-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt?sv=2019-07-07&sr=b&sig=ZOWWw0xGC7ApX6%2Fl7QAu%2BI10bQi8sI%2B6s4%2BLrHTye%2BY%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/65_job_prep-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt?sv=2019-07-07&sr=b&sig=I35%2BGYgZxjCzzQLb0t1vs%2FJP1opzihuB6lAN6hKQKdw%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=z5LNEQQp%2B%2F5ZNewDmrWXTiyjIOzXc5G837kp9ewvnKM%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/75_job_post-tvmps_46bbc533ae2dfa42495cb121b9795258175da64abbc6bbc67d5417d68ce2eb22_d.txt?sv=2019-07-07&sr=b&sig=pveq%2FSo8f%2Fknf8F5pE9N6jktU3aoxI3cKfef3bbORJk%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'azureml-logs/process_info.json': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/process_info.json?sv=2019-07-07&sr=b&sig=GXRXqbcpFOQ5uZK1CeGxZnDEeby%2FAK%2FhA9YeOAsHJ2Q%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'azureml-logs/process_status.json': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/azureml-logs/process_status.json?sv=2019-07-07&sr=b&sig=0Y9Rt5%2Blscb%2FQYVq8JSMJh2xXpmRbGFULhFdrzySAZk%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T16%3A56%3A26Z&ske=2021-10-07T01%3A06%3A26Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'logs/azureml/94_azureml.log': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/logs/azureml/94_azureml.log?sv=2019-07-07&sr=b&sig=emCPGR5Un60awg7jMYdnt8veNCu2VO4ZallITxMki9w%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T15%3A36%3A19Z&ske=2021-10-06T23%3A46%3A19Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/logs/azureml/job_prep_azureml.log?sv=2019-07-07&sr=b&sig=DBqCJZx2oP5Z25Umw3gMedset%2FreUUvYibY%2FX3rskCY%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T15%3A36%3A19Z&ske=2021-10-06T23%3A46%3A19Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://amlmstutstorageaac522ec0.blob.core.windows.net/azureml/ExperimentRun/dcid.exp-007_1633455195_d27edee9/logs/azureml/job_release_azureml.log?sv=2019-07-07&sr=b&sig=ub%2BOtkvaGLmbgARtZGoQdEUcd2PtVnCFwziCX5ariAQ%3D&skoid=e53d356d-d897-4c01-860f-b0c035994e1c&sktid=68fda48c-5b34-479d-91f9-034da6f0efe3&skt=2021-10-05T15%3A36%3A19Z&ske=2021-10-06T23%3A46%3A19Z&sks=b&skv=2019-07-07&st=2021-10-05T17%3A34%3A22Z&se=2021-10-06T01%3A44%3A22Z&sp=r'},
#  'submittedBy': 'Roshan Koirala'}

# %% [markdown]
# # Delete compute cluster
#
# `Compute` resources on the cloud are one of the most expensive one. So after the use it is good idea to delete the cluster. We may also stop but it may charge some money still.

# %%
rk_cluster.delete()
