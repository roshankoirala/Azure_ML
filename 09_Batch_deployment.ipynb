# %%
from azureml.core import Workspace, Experiment, Environment
from azureml.core.environment import CondaDependencies
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.data import OutputFileDatasetConfig
from azureml.pipeline.core import Pipeline, PipelineData
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import ScheduleRecurrence, Schedule
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (numpy 1.20.2 (c:\users\rkoirala\anaconda3\lib\site-packages), Requirement.parse('numpy<=1.19.3; sys_platform == "win32"'), {'azureml-dataset-runtime'}).

# %%
ws = Workspace.from_config()

# %%
myenv = Environment(name='env_azure_pipeline')
myenv_dep = CondaDependencies.create(conda_packages=['pandas', 'scikit-learn', 'pip'], 
                                    pip_packages=['azureml-sdk', 'azureml-dataset-runtime', 
                                                 'azureml-dataset-runtime[fuse,pandas]'])
myenv.python.conda_dependencies = myenv_dep
myenv.register(ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "env_azure_pipeline",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-sdk~=1.30.0",
#                         "azureml-dataset-runtime[fuse,pandas]~=1.30.0"
#                     ]
#                 },
#                 "pandas",
#                 "scikit-learn",
#                 "pip"
#             ],
#             "name": "azureml_a3d9dd06675f6250dab3e82ffd329a2b"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "6"
# }

# %%
compute_name = 'rk-test-compute'
compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', 
                                                       max_nodes=2)

rk_cluster = ComputeTarget.create(ws, compute_name, compute_config)
rk_cluster.wait_for_completion(show_output=True)
# Out:
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# # How to make this work?

# %% [markdown]
# ```python
# import joblib
# import pandas as pd
# from azureml.core import Model
#
# model_path = Model.get_model_path('classification_model',
#                                   _workspace=ws)
# model = joblib.load(model_path)
#
#
# batch_data_df = batch_data.to_pandas_dataframe()
# # X = batch_data_df.drop('y', axis=1)
# model.predict(batch_data_df)
# ```

# %% [markdown]
# # Run experiment

# %%
parallel_run_config = ParallelRunConfig(source_directory='.',
                                        entry_script="batch_scoring_script_1.py",
                                        mini_batch_size="5",
                                        error_threshold=10,
                                        output_action="append_row",
                                        environment=myenv,
                                        compute_target=rk_cluster,
                                        node_count=2)

# %%
# Registered model name 
model_used = 'demo_iris_model'

# this is our batch data to make predictions 
batch_data = ws.datasets['Iris Data'] 

# Setting up output folder 
default_ds = ws.get_default_datastore()
output_dir = PipelineData(name='batch_inference', 
                          datastore=default_ds)

# output_dir = OutputFileDatasetConfig(name='batch_inferences')

# %%
parallel_run_step = ParallelRunStep(name='batch-score', 
                                   parallel_run_config=parallel_run_config,
                                   inputs=[batch_data.as_named_input('batch_data')],
                                   output=output_dir,
                                   arguments=[],
                                   allow_reuse=True)

pipeline = Pipeline(workspace=ws, 
                    steps=[parallel_run_step])

# %%
pipeline_run = Experiment(workspace=ws, 
                         name='batch_prediction_pipeline').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score [c9080ca5][8a73242c-2fd3-4ead-81c5-51892f392dad], (This step will run and generate new outputs)
# Submitted PipelineRun 7e37da03-9c99-4034-bdba-157c147598a5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/7e37da03-9c99-4034-bdba-157c147598a5?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# PipelineRunId: 7e37da03-9c99-4034-bdba-157c147598a5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/7e37da03-9c99-4034-bdba-157c147598a5?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: d1711bf3-a6dd-4393-8509-5829bd3404bd
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/d1711bf3-a6dd-4393-8509-5829bd3404bd?wsid=/subscriptions/54245888-2ffe-41fa-b080-67a29997b41c/resourcegroups/rg-dataservices-sandbox-01/workspaces/ds_dev_01&tid=4ef6e02a-f252-4618-a1dc-03bd2f93157d
# StepRun( batch-score ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/10/12 18:02:25 Downloading source code...
# 2021/10/12 18:02:26 Finished downloading source code
# 2021/10/12 18:02:27 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/10/12 18:02:27 Successfully set up Docker network: acb_default_network
# 2021/10/12 18:02:27 Setting up Docker configuration...
# 2021/10/12 18:02:28 Successfully set up Docker configuration
# 2021/10/12 18:02:28 Logging in to registry: 0319839584634a4d8899cb105b49c173.azurecr.io
# 2021/10/12 18:02:28 Successfully logged into 0319839584634a4d8899cb105b49c173.azurecr.io
# 2021/10/12 18:02:28 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/12 18:02:28 Scanning for dependencies...
# 2021/10/12 18:02:29 Successfully scanned dependencies
# 2021/10/12 18:02:29 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1@sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1@sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 01bf7da0a88c: Pulling fs layer
# f3b4a5f15c7a: Pulling fs layer
# 57ffbe87baa1: Pulling fs layer
# 86120caa19f5: Pulling fs layer
# c0f2d44469de: Pulling fs layer
# 638bc09d59ce: Pulling fs layer
# cec7eddb8044: Pulling fs layer
# 31cda9815495: Pulling fs layer
# a1b48f84f0d1: Pulling fs layer
# 484f821166bc: Pulling fs layer
# 6d70e314b196: Pulling fs layer
# 86120caa19f5: Waiting
# c0f2d44469de: Waiting
# 638bc09d59ce: Waiting
# cec7eddb8044: Waiting
# 31cda9815495: Waiting
# a1b48f84f0d1: Waiting
# 484f821166bc: Waiting
# 6d70e314b196: Waiting
# 57ffbe87baa1: Verifying Checksum
# 57ffbe87baa1: Download complete
# f3b4a5f15c7a: Verifying Checksum
# f3b4a5f15c7a: Download complete
# 01bf7da0a88c: Verifying Checksum
# 01bf7da0a88c: Download complete
# c0f2d44469de: Verifying Checksum
# c0f2d44469de: Download complete
# 01bf7da0a88c: Pull complete
# 638bc09d59ce: Verifying Checksum
# 638bc09d59ce: Download complete
# f3b4a5f15c7a: Pull complete
# 57ffbe87baa1: Pull complete
# 31cda9815495: Verifying Checksum
# 31cda9815495: Download complete
# cec7eddb8044: Verifying Checksum
# cec7eddb8044: Download complete
# a1b48f84f0d1: Verifying Checksum
# a1b48f84f0d1: Download complete
# 484f821166bc: Verifying Checksum
# 484f821166bc: Download complete
# 6d70e314b196: Download complete
#
# 86120caa19f5: Verifying Checksum
# 86120caa19f5: Download complete
# 86120caa19f5: Pull complete
# c0f2d44469de: Pull complete
# 638bc09d59ce: Pull complete
# cec7eddb8044: Pull complete
# 31cda9815495: Pull complete
# a1b48f84f0d1: Pull complete
# 484f821166bc: Pull complete
# 6d70e314b196: Pull complete
# Digest: sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1@sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
#  ---> 63a0a67d2c72
# Step 2/19 : USER root
#  ---> Running in 0c7f6d77825f
# Removing intermediate container 0c7f6d77825f
#  ---> 7581bcb8dcae
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in da8bd27a319c
# Removing intermediate container da8bd27a319c
#  ---> 0bee6db0ab9d
# Step 4/19 : WORKDIR /
#  ---> Running in c727a6820d4f
# Removing intermediate container c727a6820d4f
#  ---> 8d341c9fc99b
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 0f5938ec51e4
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 7a1c9fbde3ca
# Removing intermediate container 7a1c9fbde3ca
#  ---> 7df7cba8c008
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 8be597dd66af
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 4456db87140d
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | 7          |   8%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #########7 |  97%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | #          |  10%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #8         |  19%
# openssl-1.0.2u       | 3.1 MB    | ######4    |  65%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ####       |  40%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##3        |  23%
# python-3.6.2         | 27.0 MB   | #####6     |  57%
# python-3.6.2         | 27.0 MB   | ########1  |  81%
# python-3.6.2         | 27.0 MB   | #########7 |  98%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ###1       |  31%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##2        |  23%
# scipy-1.5.2          | 18.5 MB   | ######     |  60%
# scipy-1.5.2          | 18.5 MB   | #########3 |  93%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 1          |   2%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | 9          |   9%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #8         |  19%
# mkl-2019.4           | 204.1 MB  | ##2        |  22%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###6       |  37%
# mkl-2019.4           | 204.1 MB  | ###9       |  40%
# mkl-2019.4           | 204.1 MB  | ####2      |  43%
# mkl-2019.4           | 204.1 MB  | ####5      |  46%
# mkl-2019.4           | 204.1 MB  | ####8      |  48%
# mkl-2019.4           | 204.1 MB  | #####1     |  51%
# mkl-2019.4           | 204.1 MB  | #####4     |  54%
# mkl-2019.4           | 204.1 MB  | #####7     |  57%
# mkl-2019.4           | 204.1 MB  | ######     |  60%
# mkl-2019.4           | 204.1 MB  | ######2    |  63%
# mkl-2019.4           | 204.1 MB  | ######5    |  65%
# mkl-2019.4           | 204.1 MB  | ######7    |  68%
# mkl-2019.4           | 204.1 MB  | #######    |  70%
# mkl-2019.4           | 204.1 MB  | #######2   |  73%
# mkl-2019.4           | 204.1 MB  | #######5   |  76%
# mkl-2019.4           | 204.1 MB  | #######8   |  79%
# mkl-2019.4           | 204.1 MB  | ########   |  81%
# mkl-2019.4           | 204.1 MB  | ########3  |  83%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####3      |  43%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ####1      |  41%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.zmeaeihz.requirements.txt']
# Pip subprocess output:
# Collecting azureml-sdk~=1.30.0
#   Downloading azureml_sdk-1.30.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-dataset-runtime[fuse,pandas]~=1.30.0
#   Downloading azureml_dataset_runtime-1.30.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-train-automl-client~=1.30.0
#   Downloading azureml_train_automl_client-1.30.0-py3-none-any.whl (120 kB)
# Collecting azureml-core~=1.30.0
#   Downloading azureml_core-1.30.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-pipeline~=1.30.0
#   Downloading azureml_pipeline-1.30.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train~=1.30.0
#   Downloading azureml_train-1.30.0-py3-none-any.whl (3.3 kB)
# Requirement already satisfied, skipping upgrade: numpy!=1.19.3; sys_platform == "linux" in /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.30.0->-r /azureml-environment-setup/condaenv.zmeaeihz.requirements.txt (line 2)) (1.19.1)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.16.0a,>=2.15.0a
#   Downloading azureml_dataprep-2.15.1-py3-none-any.whl (39.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.30.0->-r /azureml-environment-setup/condaenv.zmeaeihz.requirements.txt (line 2)) (1.1.3)
# Collecting azureml-telemetry~=1.30.0
#   Downloading azureml_telemetry-1.30.0-py3-none-any.whl (30 kB)
# Collecting azureml-automl-core~=1.30.0
#   Downloading azureml_automl_core-1.30.0-py3-none-any.whl (207 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.2.0-py3-none-any.whl (16 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/python3.6/site-packages (from azureml-core~=1.30.0->azureml-sdk~=1.30.0->-r /azureml-environment-setup/condaenv.zmeaeihz.requirements.txt (line 1)) (2.8.1)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/python3.6/site-packages (from azureml-core~=1.30.0->azureml-sdk~=1.30.0->-r /azureml-environment-setup/condaenv.zmeaeihz.requirements.txt (line 1)) (2020.1)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azureml-pipeline-steps~=1.30.0
#   Downloading azureml_pipeline_steps-1.30.0-py3-none-any.whl (69 kB)
# Collecting azureml-pipeline-core~=1.30.0
#   Downloading azureml_pipeline_core-1.30.0-py3-none-any.whl (311 kB)
# Collecting azureml-train-core~=1.30.0
#   Downloading azureml_train_core-1.30.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.14.0a,>=1.13.0dev0
#   Downloading azureml_dataprep_rslex-1.13.0-cp36-cp36m-manylinux2010_x86_64.whl (9.8 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied, skipping upgrade: six>=1.4.0 in /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/python3.6/site-packages (from docker<5.0.0->azureml-core~=1.30.0->azureml-sdk~=1.30.0->-r /azureml-environment-setup/condaenv.zmeaeihz.requirements.txt (line 1)) (1.15.0)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.30.0->azureml-sdk~=1.30.0->-r /azureml-environment-setup/condaenv.zmeaeihz.requirements.txt (line 1)) (2020.6.20)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.30.0
#   Downloading azureml_train_restclients_hyperdrive-1.30.0-py3-none-any.whl (19 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.15.0-py2.py3-none-any.whl (77 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.19.0-py2.py3-none-any.whl (176 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=b3deeeab8c9be080caf070f7a8fd35f385474cb8abbe9b8fa1408891439c3a20
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: pyarrow, azureml-dataprep-native, cloudpickle, urllib3, charset-normalizer, idna, requests, pycparser, cffi, cryptography, PyJWT, msal, azure-core, portalocker, msal-extensions, azure-identity, azureml-dataprep-rslex, distro, dotnetcore2, azureml-dataprep, fusepy, azureml-dataset-runtime, ruamel.yaml.clib, ruamel.yaml, websocket-client, docker, adal, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-common, azure-mgmt-storage, jeepney, SecretStorage, contextlib2, pyopenssl, azure-graphrbac, jmespath, backports.weakref, backports.tempfile, pyasn1, ndg-httpsclient, pathspec, azure-mgmt-authorization, typing-extensions, zipp, importlib-metadata, jsonpickle, azure-mgmt-resource, azure-mgmt-core, azure-mgmt-containerregistry, azure-mgmt-keyvault, azureml-core, applicationinsights, azureml-telemetry, azureml-automl-core, azureml-train-automl-client, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-train, azureml-sdk
# Successfully installed PyJWT-2.2.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.19.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-automl-core-1.30.0 azureml-core-1.30.0 azureml-dataprep-2.15.1 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.13.0 azureml-dataset-runtime-1.30.0 azureml-pipeline-1.30.0 azureml-pipeline-core-1.30.0 azureml-pipeline-steps-1.30.0 azureml-sdk-1.30.0 azureml-telemetry-1.30.0 azureml-train-1.30.0 azureml-train-automl-client-1.30.0 azureml-train-core-1.30.0 azureml-train-restclients-hyperdrive-1.30.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.6 charset-normalizer-2.0.7 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.4.8 distro-1.6.0 docker-4.4.4 dotnetcore2-2.1.21 fusepy-3.0.1 idna-3.2 importlib-metadata-4.8.1 isodate-0.6.0 jeepney-0.7.1 jmespath-0.10.0 jsonpickle-2.0.0 msal-1.15.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 pathspec-0.9.0 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.7 websocket-client-1.2.1 zipp-3.6.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 4456db87140d
#  ---> 1b07de39e06e
# Step 9/19 : ENV PATH /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/bin:$PATH
#  ---> Running in fc64a06810a1
# Removing intermediate container fc64a06810a1
#  ---> 61d581826ca5
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 579e03bf9846
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 93f1a5bccef1
# Copying environment context
# Removing intermediate container 93f1a5bccef1
#  ---> aa845aaec585
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 92afee4274df
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b
#  ---> Running in 19871d84b085
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 19871d84b085
#  ---> d71079d15562
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b
#  ---> Running in 238b70938d9f
# Removing intermediate container 238b70938d9f
#  ---> ff0f79311d6e
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib:$LD_LIBRARY_PATH
#  ---> Running in d171d1c28399
# Removing intermediate container d171d1c28399
#  ---> f3972ee0be91
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> bcf8dab6472a
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 39c6ec87edc7
# Removing intermediate container 39c6ec87edc7
#  ---> ee5c18f5ee87
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in ad0f2d7b17fb
# Removing intermediate container ad0f2d7b17fb
#  ---> 5aa0e2184c4e
# Step 19/19 : CMD ["bash"]
#  ---> Running in 0bf5eb216d27
# Removing intermediate container 0bf5eb216d27
#  ---> ed3163828eb7
# Successfully built ed3163828eb7
# Successfully tagged 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:latest
# Successfully tagged 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:1
# 2021/10/12 18:11:38 Successfully executed container: acb_step_0
# 2021/10/12 18:11:38 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/12 18:11:38 Pushing image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:1, attempt 1
# The push refers to repository [0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960]
# f05f26f0f6bc: Preparing
# 67a0dd44a613: Preparing
# 3d9c377d1356: Preparing
# 028ff363b741: Preparing
# 1ecc998f8be1: Preparing
# d46b11d27803: Preparing
# d311444e0b19: Preparing
# 0b407645aaa1: Preparing
# f8f29be99ea4: Preparing
# 79dc78335362: Preparing
# cd522a282582: Preparing
# 5ffe0b2ed9b9: Preparing
# edf4c99a758a: Preparing
# 28f3c2496426: Preparing
# 3df6d6ce3c09: Preparing
# 708986b6155f: Preparing
# d4ac134e30e9: Preparing
# 8cafc6d2db45: Preparing
# a5d4bacb0351: Preparing
# 5153e1acaabc: Preparing
# d46b11d27803: Waiting
# d311444e0b19: Waiting
# 0b407645aaa1: Waiting
# f8f29be99ea4: Waiting
# 79dc78335362: Waiting
# cd522a282582: Waiting
# 5ffe0b2ed9b9: Waiting
# edf4c99a758a: Waiting
# 28f3c2496426: Waiting
# 3df6d6ce3c09: Waiting
# 708986b6155f: Waiting
# d4ac134e30e9: Waiting
# 8cafc6d2db45: Waiting
# a5d4bacb0351: Waiting
# 5153e1acaabc: Waiting
# f05f26f0f6bc: Pushed
# 028ff363b741: Pushed
# 3d9c377d1356: Pushed
# 67a0dd44a613: Pushed
# d46b11d27803: Pushed
# d311444e0b19: Pushed
# 0b407645aaa1: Pushed
# f8f29be99ea4: Pushed
# 79dc78335362: Pushed
# cd522a282582: Pushed
# edf4c99a758a: Pushed
# 5ffe0b2ed9b9: Pushed
# 708986b6155f: Pushed
# 3df6d6ce3c09: Pushed
# 8cafc6d2db45: Pushed
# a5d4bacb0351: Pushed
#
# 5153e1acaabc: Pushed
# 28f3c2496426: Pushed
# d4ac134e30e9: Pushed
# 1ecc998f8be1: Pushed
# 1: digest: sha256:ea912417d6701af010a289a5398720c669a0523470e9b81866a911fc395df5e8 size: 4514
# 2021/10/12 18:13:09 Successfully pushed image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:1
# 2021/10/12 18:13:09 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/10/12 18:13:09 Pushing image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:latest, attempt 1
# The push refers to repository [0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960]
# f05f26f0f6bc: Preparing
# 67a0dd44a613: Preparing
# 3d9c377d1356: Preparing
# 028ff363b741: Preparing
# 1ecc998f8be1: Preparing
# d46b11d27803: Preparing
# d311444e0b19: Preparing
# 0b407645aaa1: Preparing
# f8f29be99ea4: Preparing
# 79dc78335362: Preparing
# cd522a282582: Preparing
# 5ffe0b2ed9b9: Preparing
# edf4c99a758a: Preparing
# 28f3c2496426: Preparing
# 3df6d6ce3c09: Preparing
# 708986b6155f: Preparing
# d4ac134e30e9: Preparing
# 8cafc6d2db45: Preparing
# a5d4bacb0351: Preparing
# 5153e1acaabc: Preparing
# d311444e0b19: Waiting
# 0b407645aaa1: Waiting
# f8f29be99ea4: Waiting
# 79dc78335362: Waiting
# cd522a282582: Waiting
# 5ffe0b2ed9b9: Waiting
# edf4c99a758a: Waiting
# 28f3c2496426: Waiting
# 3df6d6ce3c09: Waiting
# 708986b6155f: Waiting
# d4ac134e30e9: Waiting
# 8cafc6d2db45: Waiting
# a5d4bacb0351: Waiting
# 5153e1acaabc: Waiting
# d46b11d27803: Waiting
# 1ecc998f8be1: Layer already exists
# 67a0dd44a613: Layer already exists
# 028ff363b741: Layer already exists
# f05f26f0f6bc: Layer already exists
# 3d9c377d1356: Layer already exists
# d311444e0b19: Layer already exists
# d46b11d27803: Layer already exists
# f8f29be99ea4: Layer already exists
# 0b407645aaa1: Layer already exists
# 79dc78335362: Layer already exists
# 5ffe0b2ed9b9: Layer already exists
# cd522a282582: Layer already exists
# 28f3c2496426: Layer already exists
# edf4c99a758a: Layer already exists
# 3df6d6ce3c09: Layer already exists
# 708986b6155f: Layer already exists
# 8cafc6d2db45: Layer already exists
# d4ac134e30e9: Layer already exists
# a5d4bacb0351: Layer already exists
# 5153e1acaabc: Layer already exists
# latest: digest: sha256:ea912417d6701af010a289a5398720c669a0523470e9b81866a911fc395df5e8 size: 4514
# 2021/10/12 18:13:15 Successfully pushed image: 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:latest
# 2021/10/12 18:13:15 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 549.275129)
# 2021/10/12 18:13:15 Populating digests for step ID: acb_step_0...
# 2021/10/12 18:13:17 Successfully populated digests for step ID: acb_step_0
# 2021/10/12 18:13:17 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 91.251663)
# 2021/10/12 18:13:17 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.395917)
# 2021/10/12 18:13:17 The following dependencies were found:
# 2021/10/12 18:13:17
# - image:
#     registry: 0319839584634a4d8899cb105b49c173.azurecr.io
#     repository: azureml/azureml_fd4c267b43591d24118d62beb84a2960
#     tag: latest
#     digest: sha256:ea912417d6701af010a289a5398720c669a0523470e9b81866a911fc395df5e8
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210513.v1
#     digest: sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
#   git: {}
# - image:
#     registry: 0319839584634a4d8899cb105b49c173.azurecr.io
#     repository: azureml/azureml_fd4c267b43591d24118d62beb84a2960
#     tag: "1"
#     digest: sha256:ea912417d6701af010a289a5398720c669a0523470e9b81866a911fc395df5e8
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210513.v1
#     digest: sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
#   git: {}
#
#
# Run ID: ch8 was successful after 10m52s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_1bc3dbe3729e089bff7d8c4b3117035651bf9b4647a93f48cf713623ed1a0088_d.txt
# ========================================================================================================================
# 2021-10-12T18:24:20Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24758 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-10-12T18:24:21Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/mounts/workspaceblobstore
# 2021-10-12T18:24:21Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-12T18:24:21Z Starting output-watcher...
# 2021-10-12T18:24:21Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-10-12T18:24:22Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-10-12T18:24:22Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-10-12T18:24:22Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2021-10-12T18:24:23Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_fd4c267b43591d24118d62beb84a2960
# 01bf7da0a88c: Pulling fs layer
# f3b4a5f15c7a: Pulling fs layer
# 57ffbe87baa1: Pulling fs layer
# 86120caa19f5: Pulling fs layer
# c0f2d44469de: Pulling fs layer
# 638bc09d59ce: Pulling fs layer
# cec7eddb8044: Pulling fs layer
# 31cda9815495: Pulling fs layer
# a1b48f84f0d1: Pulling fs layer
# 484f821166bc: Pulling fs layer
# 6d70e314b196: Pulling fs layer
# 4c3b25cfbfa1: Pulling fs layer
# 632de08133ce: Pulling fs layer
# 64feec91fced: Pulling fs layer
# b2bed34b31d7: Pulling fs layer
# a756b52c6d13: Pulling fs layer
# c77ef6c8a315: Pulling fs layer
# 6aaa56e805a7: Pulling fs layer
# 314a55c66e31: Pulling fs layer
# d8f2229879fe: Pulling fs layer
# 86120caa19f5: Waiting
# c0f2d44469de: Waiting
# 638bc09d59ce: Waiting
# cec7eddb8044: Waiting
# 31cda9815495: Waiting
# a1b48f84f0d1: Waiting
# 484f821166bc: Waiting
# 6d70e314b196: Waiting
# 4c3b25cfbfa1: Waiting
# 632de08133ce: Waiting
# 64feec91fced: Waiting
# b2bed34b31d7: Waiting
# a756b52c6d13: Waiting
# c77ef6c8a315: Waiting
# 6aaa56e805a7: Waiting
# 314a55c66e31: Waiting
# d8f2229879fe: Waiting
# 57ffbe87baa1: Download complete
# f3b4a5f15c7a: Verifying Checksum
# f3b4a5f15c7a: Download complete
# 01bf7da0a88c: Verifying Checksum
# 01bf7da0a88c: Download complete
# c0f2d44469de: Verifying Checksum
# c0f2d44469de: Download complete
# 638bc09d59ce: Verifying Checksum
# 638bc09d59ce: Download complete
# 31cda9815495: Verifying Checksum
# 31cda9815495: Download complete
# 01bf7da0a88c: Pull complete
# a1b48f84f0d1: Verifying Checksum
# a1b48f84f0d1: Download complete
# f3b4a5f15c7a: Pull complete
# 57ffbe87baa1: Pull complete
# 86120caa19f5: Verifying Checksum
# 86120caa19f5: Download complete
# 6d70e314b196: Verifying Checksum
# 6d70e314b196: Download complete
# 4c3b25cfbfa1: Verifying Checksum
# 4c3b25cfbfa1: Download complete
# 632de08133ce: Verifying Checksum
# 632de08133ce: Download complete
# 484f821166bc: Verifying Checksum
# 484f821166bc: Download complete
# 64feec91fced: Verifying Checksum
# 64feec91fced: Download complete
# b2bed34b31d7: Verifying Checksum
# b2bed34b31d7: Download complete
# c77ef6c8a315: Verifying Checksum
# c77ef6c8a315: Download complete
# 6aaa56e805a7: Verifying Checksum
# 6aaa56e805a7: Download complete
# cec7eddb8044: Verifying Checksum
# cec7eddb8044: Download complete
# 314a55c66e31: Verifying Checksum
# 314a55c66e31: Download complete
# d8f2229879fe: Verifying Checksum
# d8f2229879fe: Download complete
# 86120caa19f5: Pull complete
# c0f2d44469de: Pull complete
# 638bc09d59ce: Pull complete
# cec7eddb8044: Pull complete
# a756b52c6d13: Verifying Checksum
# a756b52c6d13: Download complete
# 31cda9815495: Pull complete
# a1b48f84f0d1: Pull complete
# 484f821166bc: Pull complete
# 6d70e314b196: Pull complete
# 4c3b25cfbfa1: Pull complete
# 632de08133ce: Pull complete
# 64feec91fced: Pull complete
# b2bed34b31d7: Pull complete
# a756b52c6d13: Pull complete
# c77ef6c8a315: Pull complete
# 6aaa56e805a7: Pull complete
# 314a55c66e31: Pull complete
# d8f2229879fe: Pull complete
# Digest: sha256:ea912417d6701af010a289a5398720c669a0523470e9b81866a911fc395df5e8
# Status: Downloaded newer image for 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:latest
# 0319839584634a4d8899cb105b49c173.azurecr.io/azureml/azureml_fd4c267b43591d24118d62beb84a2960:latest
# 2021-10-12T18:24:50Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-10-12T18:24:50Z Check if container d1711bf3-a6dd-4393-8509-5829bd3404bd already exist exited with 0,
#
# 7dc2971a6d6598d8342a3b057b5547b2af2c3477ebea644a6151e5c6de41d5ad
# 2021-10-12T18:24:56Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to true
# 2021-10-12T18:24:56Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-3f7eb5a42a63820923b97a4aac3e98a2-9d8fcc705f6ee014-01 -sshRequired=true]
# 2021/10/12 18:24:57 Got JobInfoJson from env
# 2021/10/12 18:24:57 Starting App Insight Logger for task:  containerSetup
# 2021/10/12 18:24:57 Version: 3.0.01734.0003 Branch: .SourceBranch Commit: 21dafbb
# 2021/10/12 18:24:57 Entered ContainerSetupTask - Preparing infiniband
# 2021/10/12 18:24:57 Starting infiniband setup
# 2021/10/12 18:24:57 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/10/12 18:24:57 Returning Python Version as 3.6
# 2021/10/12 18:24:57 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021-10-12T18:24:57Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/10/12 18:24:57 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/10/12 18:24:57 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/10/12 18:24:57 Not setting up Infiniband in Container
# 2021/10/12 18:24:57 Not setting up Infiniband in Container
# 2021-10-12T18:24:57Z Not setting up Infiniband in Container
# 2021/10/12 18:24:57 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/10/12 18:24:57 Returning Python Version as 3.6
# 2021/10/12 18:24:57 Starting setupPasswordLessSSH setup
# 2021/10/12 18:24:57 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_a3d9dd06675f6250dab3e82ffd329a2b/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: generating new host keys: DSA
# 2021/10/12 18:24:57 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/10/12 18:24:57 App Insight Client has already been closed
# 2021/10/12 18:24:57 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-10-12T18:24:57Z Starting docker container succeeded.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/10/12 18:25:09 Got JobInfoJson from env
# 2021/10/12 18:25:09 Starting App Insight Logger for task:  runTaskLet
# 2021/10/12 18:25:09 Version: 3.0.01734.0003 Branch: .SourceBranch Commit: 21dafbb
# 2021/10/12 18:25:09 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/10/12 18:25:09 Send process info logs to master server succeeded
# 2021/10/12 18:25:09 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/10/12 18:25:09 Send process info logs to master server succeeded
# [2021-10-12T18:25:09.291270] Entering context manager injector.
# [2021-10-12T18:25:09.723903] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_scoring_script_1.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/mounts/workspaceblobstore/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/batch_inference', '--input_ds_0', 'batch_data'])
# Script type = None
# [2021-10-12T18:25:09.727405] Entering Run History Context Manager.
# [2021-10-12T18:25:10.776231] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/wd/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd
# [2021-10-12T18:25:10.776442] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_scoring_script_1.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/mounts/workspaceblobstore/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/batch_inference', '--input_ds_0', 'batch_data']
# [2021-10-12T18:25:10.776471] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_scoring_script_1.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/ds_dev_01/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/mounts/workspaceblobstore/azureml/d1711bf3-a6dd-4393-8509-5829bd3404bd/batch_inference', '--input_ds_0', 'batch_data']
#
# 2021/10/12 18:25:14 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# [2021-10-12T18:30:50.055153] The experiment failed. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 4 items cleaning up...
# Cleanup took 0.19381427764892578 seconds
# azureml_common.parallel_run.exception_info.Exception: Run failed. Below is the error detail:
# EntryScriptException: Entry script error. No progress update in 270 seconds. No progress update in this check. Wait 276 seconds since last update. Remain 0 seconds to progress timeout. 152 among 543 mini batches processed. Please check logs/user/error/* and logs/sys/error/* to see if some errors have occurred.
# Processed 152 of 543 mini batches.
# The run() function in the entry script had raised exception for 212 times. Please check logs at logs/user/error/* for details.
#   * Error 'PL not found.' occurred 192 times.
#   * Error 'Failed to get input.' occurred 20 times.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "driver/amlbi_main.py", line 174, in <module>
#     main()
#   File "driver/amlbi_main.py", line 123, in main
#     boot(driver_dir)
#   File "driver/amlbi_main.py", line 58, in boot
#     booter.start()
#   File "driver/azureml_user/parallel_run/boot.py", line 372, in start
#     self.start_sys_main()
#   File "driver/azureml_user/parallel_run/boot.py", line 260, in start_sys_main
#     self.run_sys_main(cmd)
#   File "driver/azureml_user/parallel_run/boot_simulator.py", line 40, in run_sys_main
#     self.run(cmd)
#   File "driver/azureml_user/parallel_run/boot.py", line 201, in run
#     self.check_run_result(proc=proc, stdout=stdout, stderr=stderr)
#   File "driver/azureml_user/parallel_run/boot.py", line 211, in check_run_result
#     BootResult().check_result(stdout)
#   File "driver/azureml_user/parallel_run/boot_result.py", line 36, in check_result
#     raise Exception(message) from cause
# Exception: Run failed, please check logs for details. You can check logs/readme.txt for the layout of logs.
#
# [2021-10-12T18:30:50.370784] Finished context manager injector with Exception.
#
# StepRun(batch-score) Execution Summary
# =======================================
# StepRun( batch-score ) Status: Failed
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "severity": null,
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code",
#     "messageFormat": "{Message}",
#     "messageParameters": {
#       "Message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code"
#     },
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": {
#       "code": "UserTrainingScriptFailed",
#       "innerError": null
#     },
#     "debugInfo": null,
#     "additionalInfo": null
#   },
#   "correlation": {
#     "operation": "58fce888b041fc49926986592e287cda",
#     "request": "d55185d262928b97"
#   },
#   "environment": "eastus2",
#   "location": "eastus2",
#   "time": "2021-10-12T18:31:11.1388679+00:00",
#   "componentName": "globaljobdispatcher"
# }
# {
#   "error": {
#     "code": "UserError",
#     "severity": null,
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code",
#     "messageFormat": "{Message}",
#     "messageParameters": {
#       "Message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code"
#     },
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": {
#       "code": "UserTrainingScriptFailed",
#       "innerError": null
#     },
#     "debugInfo": null,
#     "additionalInfo": null
#   },
#   "correlation": {
#     "operation": "1a6fd7857bbb36438b033de3d06efe09",
#     "request": "90bdd361ec3e7e3a"
#   },
#   "environment": "eastus2",
#   "location": "eastus2",
#   "time": "2021-10-12T18:32:03.0616262+00:00",
#   "componentName": "execution-worker"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-13-67ee4b458944> in <module>
#       1 pipeline_run = Experiment(workspace=ws,
#       2                          name='batch_prediction_pipeline').submit(pipeline)
# ----> 3 pipeline_run.wait_for_completion(show_output=True)
#
# ~\Anaconda3\lib\site-packages\azureml\pipeline\core\run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     292                             print('\n')
#     293                             try:
# --> 294                                 step_run.wait_for_completion(timeout_seconds=timeout_seconds - time_elapsed,
#     295                                                              raise_on_error=raise_on_error)
#     296                             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\azureml\pipeline\core\run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     734         if show_output:
#     735             try:
# --> 736                 return self._stream_run_output(timeout_seconds=timeout_seconds,
#     737                                                raise_on_error=raise_on_error)
#     738             except KeyboardInterrupt:
#
# ~\Anaconda3\lib\site-packages\azureml\pipeline\core\run.py in _stream_run_output(self, timeout_seconds, raise_on_error)
#     823             print(json.dumps(error, indent=4))
#     824         if error and raise_on_error:
# --> 825             raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     826
#     827         print(final_details)
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with Exception: Run failed, please check logs for details. You can check logs/readme.txt for the layout of logs.",
#         "messageParameters": {},
#         "detailsUri": "https://aka.ms/azureml-known-errors",
#         "details": []
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with Exception: Run failed, please check logs for details. You can check logs/readme.txt for the layout of logs.\",\n        \"messageParameters\": {},\n        \"detailsUri\": \"https://aka.ms/azureml-known-errors\",\n        \"details\": []\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }

# %% [markdown]
# ```python
# prediction_run = next(pipeline_run.get_childern())
# prediction_output = prediction_run.get_output_data('batch_inference')
# prediction_output.download(local_path='results')
# ```

# %% [markdown]
# # Deploy
#
# ```python
# published_pipeline = pipeline_run.publish_pipeline(name='batch_prediction_pipeline',
#                                                    description='Batch pipeline demo',
#                                                    version='1.0')
# print('Published Pipeline', published_pipeline)
#
# rest_endpoint = published_pipeline.endpoint
# print('Rest Endpoint', rest_endpoint)
#
# hourly = ScheduleRecurrence(frequency='Hour', interval=1)
# pipeline_schedule = Schedule.create(workspace=ws,
#                                    name='trains model hourly',
#                                    pipeline_id=published_pipeline.id,
#                                    experiment_name='batch_prediction_pipeline',
#                                    recurrence=hourly)
# print('Pipeline Schedule', pipeline_schedule)
# ```

# %% [markdown]
# # Deleting things

# %%
pipeline_schedule.disable()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b02a7c66a196> in <module>
# ----> 1 pipeline_schedule.disable()
#
# NameError: name 'pipeline_schedule' is not defined

# %%
rk_cluster.delete()
